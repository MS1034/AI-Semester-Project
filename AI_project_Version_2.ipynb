# %%
import time
import random
import copy
from math import ceil, log2
from tabulate import tabulate
import math

class Group:
    groups = None

    def __init__(self, name, size):
        self.name = name
        self.size = size

    @staticmethod
    def find(name):
        for i in range(len(Group.groups)):
            if Group.groups[i].name == name:
                return i
        return -1

    def __repr__(self):
        return "Group: " + self.name + ", Size: " + str(self.size)


class Professor:
    professors = None

    def __init__(self, name):
        self.name = name

    @staticmethod
    def find(name):
        for i in range(len(Professor.professors)):
            if Professor.professors[i].name == name:
                return i
        return -1

    def __repr__(self):
        return "Professor: " + self.name


class CourseClass:
    classes = None

    def __init__(self, code, cr, is_lab=False, fullName=None):
        self.code = code
        self.is_lab = not is_lab
        self.fullName = fullName
        self.cr = cr

    @staticmethod
    def find(code):
        for i in range(len(CourseClass.classes)):
            if CourseClass.classes[i].code == code:
                return i
        return -1

    def __repr__(self):
        return "CourseClass: " + self.code


class Room:
    rooms = None

    def __init__(self, name, size, is_lab=False):
        self.name = name
        self.size = size
        self.is_lab = is_lab

    @staticmethod
    def find(name):
        for i in range(len(Room.rooms)):
            if Room.rooms[i].name == name:
                return i
        return -1

    def __repr__(self):
        return "Room: " + self.name + " Size: " + str(self.size)


class Slot:
    slots = None

    def __init__(self, start, end, day, is_lab_slot=False):
        self.start = start
        self.end = end
        self.day = day
        self.is_lab_slot = is_lab_slot

    def __repr__(self):
        return "Slot: " + self.start + "-" + self.end + " Day: " + self.day

# Section
Group.groups = [Group("A20", 43), Group("B20", 50), Group(
    "C20", 30), Group("A21", 43), Group("B21", 50), Group(
    "C21", 30), Group("D21", 43), Group("A22", 43), Group("B22", 50), Group(
    "C22", 30), Group("D22", 43), Group("A23", 43), Group("B23", 50), Group(
    "C23", 30), Group("D23", 43)]


Professor.professors = [
    Professor("Dr. Talha Waheed"),
    Professor("Ms. Aaliya"),
    Professor("Dr. Usman Ghani"),
    Professor("Department of Islamic Studies"),
    Professor("Dr. Khaldoon"),
    Professor("Nauman Shafee"),
    Professor("Dr. Junaid Arshad"),
    Professor("Ms. Aroosh"),
    Professor("Ms. Aroosh"),
    Professor("Prof. Dr. M. Aslam"),
    Professor("Mr. Samyan Qayyum"),
    Professor("Ms. Tazeem"),
    Professor("Dr. Faiza Iqbal"),
    Professor("Mr. Aatif Hussain"),
    Professor("Prof. Dr. Shazia Arshad"),
    Professor("Mr. Laeeq uz Zaman"),
    Professor("Dr. Amjad Farooq"),
    Professor("Mr. Waseem"),
    Professor("Mr. Nazeef ul Haq"),
    Professor("Mr. Faraz"),
    Professor("Humanities Department II"),
    Professor("Mr. Tauqir Ahmed"),
    Professor("Mr. Tehseen"),
    Professor("Mathematics Department II"),
    Professor("Dr. Ayesha Altaf"),
    Professor("Dr. Awais Hassan"),
    Professor("Ms. Maida"),
    Professor("Ms. Ramsha Khalid"),
    Professor("Ms. Abqa Javed"),
    Professor("Dr. Amna Zafar"),
    Professor("Waqas Ali"),
    Professor("Humanities Department I"),
    Professor("Mathematics Department I"),
    Professor("Mechanical Department I"),

]

CourseClass.classes = [
    CourseClass("CC", 3, True,  "Compiler Construction"),
    CourseClass("CC (Lab)", 3, False, "Compiler Construction (Lab)"),
    CourseClass("NLP", 3, True,  "Natural Language Processing"),
    CourseClass("IPS", 3, True,  "Islamic and Pakistan Studies I"),
    CourseClass("IR", 3, True,  "Information Retrieval"),
    CourseClass("CCom", 3, True,  "Cloud Computing"),
    CourseClass("CN", 3, True,  "Computer Networks (CN)"),
    CourseClass("CN (Lab)", 3, False, "Computer Networks (Lab) (CN)"),
    CourseClass("AI", 3, True,  "Artificial Intelligence"),
    CourseClass("AI (Lab)", 3, False, "Artificial Intelligence (Lab) (AI)"),
    CourseClass("PPSD", 3, True,
                "Professional Practices in Software Development (PPSD)"),
    CourseClass("SE", 3, True,  "Software Engineering (SE)"),
    CourseClass("SE (Lab)", 3, False, "Software Engineering (Lab) (SE)"),
    CourseClass("MAD", 3, True,  "Mobile Application Development"),
    CourseClass("DSA", 3, True,  "Data Structures and Algorithms (DSA)"),
    CourseClass("DSA (Lab)", 3, False,
                "Data Structures and Algorithms (Lab) (DSA)"),
    CourseClass("TW", 3, True,
                "Technical Writing and Presentation Skills (TW)"),
    CourseClass("COAL", 3, True,
                "Computer Organization and Assembly Language (COAL)"),
    CourseClass("COAL (Lab)", 3, False,
                "Computer Organization and Assembly Language (Lab)"),
    CourseClass("LA", 3, True,  "Linear Algebra (LA)"),
    CourseClass("DMII", 3, True,  "Discrete Mathematics (DM II)"),
    CourseClass("PF", 3, True,  "Programming Fundamentals (PF)"),
    CourseClass("PF (Lab)", 3, False, "Programming Fundamentals (Lab) (PF)"),
    CourseClass("PD", 3, True,  "Programming Day (PD)"),
    CourseClass("AICT", 3, True,
                "Application of Information and Communication Technologies (AICT)"),
    CourseClass("AICT (Lab)", False,
                "Application of Information and Communication Technologies Lab (AICT) (Lab)"),
    CourseClass("DMI", 3, True,  "Discrete Mathematics (DM I)"),
    CourseClass("FE", 3, True,  "Functional English (FE)"),
    CourseClass("C", 3, True,  "Calculus (C)"),
    CourseClass("WP", 3, True,  "Workshop Practices (WP)"),
]


Room.rooms = [
    Room("N1", 60),
    Room("N2", 60),
    Room("N3", 60),
    Room("N4", 60),
    Room("N5", 60),
    Room("N6", 60),
    Room("N7", 60),
    Room("N8", 60),
    Room("N9", 60),
    Room("N10", 60),
    Room("N11", 60),
    Room("N12", 60),
    Room("lab1", 60, is_lab=True),
    Room("lab2", 60, is_lab=True),
    Room("lab3", 60, is_lab=True),
    Room("lab4", 60, is_lab=True)
]


Slot.slots = [
    Slot("08:00", "09:00", "Mon"),
    Slot("09:00", "10:00", "Mon"),
    Slot("10:00", "11:00", "Mon"),
    Slot("11:00", "12:00", "Mon"),
    # Lunch break from 12:00 PM to 1:00 PM
    Slot("13:00", "14:00", "Mon"),
    Slot("14:00", "15:00", "Mon"),
    Slot("15:00", "16:00", "Mon"),
    Slot("08:00", "09:00", "Tue"),
    Slot("09:00", "10:00", "Tue"),
    Slot("10:00", "11:00", "Tue"),
    Slot("11:00", "12:00", "Tue"),
    # Lunch break from 12:00 PM to 1:00 PM
    Slot("13:00", "14:00", "Tue"),
    Slot("14:00", "15:00", "Tue"),
    Slot("15:00", "16:00", "Tue"),
    Slot("08:00", "09:00", "Wed"),
    Slot("09:00", "10:00", "Wed"),
    Slot("10:00", "11:00", "Wed"),
    Slot("11:00", "12:00", "Wed"),
    # Lunch break from 12:00 PM to 1:00 PM
    Slot("13:00", "14:00", "Wed"),
    Slot("14:00", "15:00", "Wed"),
    Slot("15:00", "16:00", "Wed"),
    Slot("08:00", "09:00", "Thu"),
    Slot("09:00", "10:00", "Thu"),
    Slot("10:00", "11:00", "Thu"),
    Slot("11:00", "12:00", "Thu"),
    Slot("13:00", "14:00", "Thu"),
    Slot("14:00", "15:00", "Thu"),
    Slot("15:00", "16:00", "Thu"),
    Slot("08:00", "09:00", "Fri"),
    Slot("09:00", "10:00", "Fri"),
    Slot("10:00", "11:00", "Fri"),
    Slot("11:00", "12:00", "Fri"),
    # Lunch break from 12:00 PM to 1:00 PM
    Slot("13:00", "14:00", "Fri"),
    Slot("14:00", "15:00", "Fri"),
    Slot("15:00", "16:00", "Fri"),
]

# TODO
# 0.  Running Simplified Class Scheduling - Done
# 0.5 Problem Instance to Binary String - Done
# 1.  Multiple days - Done
# 2.  Class Size - Done
# 2.25 Check Selection Function - Done
# 2.5 One group can attend only one class at a time - Done
# 3.  Multiple classes - Done
# 4.  Lab - Done

# Below chromosome parts are just to teach basic

# cpg = ["000000", "010001", "100100", "111010"] # course, professor, student group pair
# lts = ["00", "01"] # lecture theatres
# slots = ["00", "01"] # time slots

# ######### Chromosome ##############
# <CourseClass, Prof, Group, Slot, LT>   #
# ###################################


max_score = None

cpg = []
lts = []
slots = []
Schedule = {}
bits_needed_backup_store = {}  # to improve performance


def bits_needed(x):
    global bits_needed_backup_store
    r = bits_needed_backup_store.get(id(x))
    if r is None:
        r = int(ceil(log2(len(x))))
        bits_needed_backup_store[id(x)] = r
    return max(r, 1)


def join_cpg_pair(_cpg):
    res = []
    for i in range(0, len(_cpg), 3):
        res.append(_cpg[i] + _cpg[i + 1] + _cpg[i + 2])
    return res


def convert_input_to_bin():
    global cpg, lts, slots, max_score

    cpg = [CourseClass.find("PF"), Professor.find("Dr. Awais Hassan"), Group.find("A23"),
           CourseClass.find("PF"), Professor.find(
               "Dr. Awais Hassan"), Group.find("B23"),
           CourseClass.find("PF"), Professor.find(
               "Mr. Laeeq uz Zaman"), Group.find("C23"),
           CourseClass.find("PF"), Professor.find(
               "Ms. Maida"), Group.find("D23"),
           CourseClass.find("PF (Lab)"), Professor.find(
               "Ms. Maida"), Group.find("A23"),
           CourseClass.find("PF (Lab)"), Professor.find(
               "Ms. Maida"), Group.find("B23"),
           CourseClass.find("PF (Lab)"), Professor.find(
               "Ms. Maida"), Group.find("C23"),
           CourseClass.find("PF (Lab)"), Professor.find(
               "Ms. Maida"), Group.find("D23"),
           CourseClass.find("AICT"), Professor.find(
               "Ms. Abqa Javed"), Group.find("A23"),
           CourseClass.find("AICT"), Professor.find(
               "Ms. Abqa Javed"), Group.find("B23"),
           CourseClass.find("AICT"), Professor.find(
               "Dr. Amna Zafar"), Group.find("C23"),
           CourseClass.find("AICT"), Professor.find(
               "Dr. Amna Zafar"), Group.find("D23"),
           CourseClass.find("AICT (Lab)"), Professor.find(
               "Ms. Abqa Javed"), Group.find("A23"),
           CourseClass.find("AICT (Lab)"), Professor.find(
               "Ms. Abqa Javed"), Group.find("B23"),
           CourseClass.find("AICT (Lab)"), Professor.find(
               "Dr. Amna Zafar"), Group.find("C23"),
           CourseClass.find("AICT (Lab)"), Professor.find(
               "Dr. Amna Zafar"), Group.find("D23"),
           CourseClass.find("DMI"), Professor.find(
               "Waqas Ali"), Group.find("A23"),
           CourseClass.find("DMI"), Professor.find(
               "Waqas Ali"), Group.find("B23"),
           CourseClass.find("DMI"), Professor.find(
               "Waqas Ali"), Group.find("C23"),
           CourseClass.find("DMI"), Professor.find(
               "Waqas Ali"), Group.find("D23"),
           CourseClass.find("FE"), Professor.find(
               "Humanities Department I"), Group.find("A23"),
           CourseClass.find("FE"), Professor.find(
               "Humanities Department I"), Group.find("B23"),
           CourseClass.find("FE"), Professor.find(
               "Humanities Department I"), Group.find("C23"),
           CourseClass.find("FE"), Professor.find(
               "Humanities Department I"), Group.find("D23"),
           CourseClass.find("C"), Professor.find(
               "Mathematics Department I"), Group.find("A23"),
           CourseClass.find("C"), Professor.find(
               "Mathematics Department I"), Group.find("B23"),
           CourseClass.find("C"), Professor.find(
               "Mathematics Department I"), Group.find("C23"),
           CourseClass.find("C"), Professor.find(
               "Mathematics Department I"), Group.find("D23"),
           CourseClass.find("WP"), Professor.find(
               "Mechanical Department I"), Group.find("A23"),
           CourseClass.find("WP"), Professor.find(
               "Mechanical Department I"), Group.find("B23"),
           CourseClass.find("WP"), Professor.find(
               "Mechanical Department I"), Group.find("C23"),
           CourseClass.find("WP"), Professor.find(
               "Mechanical Department I"), Group.find("D23"),
           CourseClass.find("DSA"),
           Professor.find("Mr. Nazeef ul Haq"),
           Group.find("A22"),
           CourseClass.find("DSA"),
           Professor.find("Mr. Nazeef ul Haq"),
           Group.find("B22"),
           CourseClass.find("DSA"),
           Professor.find("Mr. Faraz"),
           Group.find("C22"),
           CourseClass.find("DSA"),
           Professor.find("Mr. Faraz"),
           Group.find("D22"),
           CourseClass.find("DSA (Lab)"),
           Professor.find("Mr. Nazeef ul Haq"),
           Group.find("A22"),
           CourseClass.find("DSA (Lab)"),
           Professor.find("Mr. Nazeef ul Haq"),
           Group.find("B22"),
           CourseClass.find("DSA (Lab)"),
           Professor.find("Mr. Faraz"),
           Group.find("C22"),
           CourseClass.find("DSA (Lab)"),
           Professor.find("Mr. Faraz"),
           Group.find("D22"),
           CourseClass.find("TW"),
           Professor.find("Humanities Department II"),
           Group.find("A22"),
           CourseClass.find("TW"),
           Professor.find("Humanities Department II"),
           Group.find("B22"),
           CourseClass.find("TW"),
           Professor.find("Humanities Department II"),
           Group.find("C22"),
           CourseClass.find("TW"),
           Professor.find("Humanities Department II"),
           Group.find("D22"),
           CourseClass.find("COAL"),
           Professor.find("Mr. Tauqir Ahmed"),
           Group.find("A22"),
           CourseClass.find("COAL"),
           Professor.find("Mr. Tauqir Ahmed"),
           Group.find("B22"),
           CourseClass.find("COAL"),
           Professor.find("Mr. Tauqir Ahmed"),
           Group.find("C22"),
           CourseClass.find("COAL"),
           Professor.find("Mr. Tehseen"),
           Group.find("D22"),
           CourseClass.find("COAL (Lab)"),
           Professor.find("Mr. Tehseen"),
           Group.find("A22"),
           CourseClass.find("COAL (Lab)"),
           Professor.find("Mr. Tehseen"),
           Group.find("B22"),
           CourseClass.find("COAL (Lab)"),
           Professor.find("Mr. Tehseen"),
           Group.find("C22"),
           CourseClass.find("COAL (Lab)"),
           Professor.find("Mr. Tehseen"),
           Group.find("D22"),
           CourseClass.find("LA"),
           Professor.find("Mathematics Department II"),
           Group.find("A22"),
           CourseClass.find("LA"),
           Professor.find("Mathematics Department II"),
           Group.find("B22"),
           CourseClass.find("LA"),
           Professor.find("Mathematics Department II"),
           Group.find("C22"),
           CourseClass.find("LA"),
           Professor.find("Mathematics Department II"),
           Group.find("D22"),
           CourseClass.find("DMII"),
           Professor.find("Dr. Ayesha Altaf"),
           Group.find("A22"),
           CourseClass.find("DMII"),
           Professor.find("Dr. Ayesha Altaf"),
           Group.find("B22"),
           CourseClass.find("DMII"),
           Professor.find("Dr. Ayesha Altaf"),
           Group.find("C22"),
           CourseClass.find("DMII"),
           Professor.find("Dr. Ayesha Altaf"),
           Group.find("D22"),
           CourseClass.find("CN"),
           Professor.find("Dr. Junaid Arshad"),
           Group.find("A21"),
           CourseClass.find("CN"),
           Professor.find("Dr. Junaid Arshad"),
           Group.find("B21"),
           CourseClass.find("CN"),
           Professor.find("Dr. Junaid Arshad"),
           Group.find("C21"),
           CourseClass.find("CN"),
           Professor.find("Ms. Aroosh"),
           Group.find("D21"),
           CourseClass.find("CN (Lab)"),
           Professor.find("Ms. Aroosh"),
           Group.find("A21"),
           CourseClass.find("CN (Lab)"),
           Professor.find("Ms. Aroosh"),
           Group.find("B21"),
           CourseClass.find("CN (Lab)"),
           Professor.find("Ms. Aroosh"),
           Group.find("C21"),
           CourseClass.find("CN (Lab)"),
           Professor.find("Ms. Aroosh"),
           Group.find("D21"),
           CourseClass.find("AI"),
           Professor.find("Prof. Dr. M. Aslam"),
           Group.find("B21"),
           CourseClass.find("AI"),
           Professor.find("Mr. Samyan Qayyum"),
           Group.find("A21"),
           CourseClass.find("AI"),
           Professor.find("Mr. Samyan Qayyum"),
           Group.find("C21"),
           CourseClass.find("AI (Lab)"),
           Professor.find("Ms. Tazeem"),
           Group.find("A21"),
           CourseClass.find("AI (Lab)"),
           Professor.find("Ms. Tazeem"),
           Group.find("B21"),
           CourseClass.find("AI (Lab)"),
           Professor.find("Ms. Tazeem"),
           Group.find("C21"),
           CourseClass.find("AI (Lab)"),
           Professor.find("Ms. Tazeem"),
           Group.find("D21"),
           CourseClass.find("PPSD"),
           Professor.find("Dr. Faiza Iqbal"),
           Group.find("A21"),
           CourseClass.find("PPSD"),
           Professor.find("Dr. Faiza Iqbal"),
           Group.find("B21"),
           CourseClass.find("PPSD"),
           Professor.find("Dr. Faiza Iqbal"),
           Group.find("C21"),
           CourseClass.find("PPSD"),
           Professor.find("Dr. Faiza Iqbal"),
           Group.find("D21"),
           CourseClass.find("SE"),
           Professor.find("Mr. Aatif Hussain"),
           Group.find("A21"),
           CourseClass.find("SE"),
           Professor.find("Mr. Aatif Hussain"),
           Group.find("B21"),
           CourseClass.find("SE"),
           Professor.find("Prof. Dr. Shazia Arshad"),
           Group.find("C21"),
           CourseClass.find("SE"),
           Professor.find("Prof. Dr. Shazia Arshad"),
           Group.find("D21"),
           CourseClass.find("SE (Lab)"),
           Professor.find("Mr. Laeeq uz Zaman"),
           Group.find("A21"),
           CourseClass.find("SE (Lab)"),
           Professor.find("Mr. Laeeq uz Zaman"),
           Group.find("B21"),
           CourseClass.find("SE (Lab)"),
           Professor.find("Mr. Laeeq uz Zaman"),
           Group.find("C21"),
           CourseClass.find("SE (Lab)"),
           Professor.find("Mr. Laeeq uz Zaman"),
           Group.find("D21"),
           CourseClass.find("MAD"),
           Professor.find("Dr. Amjad Farooq"),
           Group.find("A21"),
           CourseClass.find("MAD"),
           Professor.find("Dr. Amjad Farooq"),
           Group.find("B21"),
           CourseClass.find("MAD"),
           Professor.find("Dr. Amjad Farooq"),
           Group.find("C21"),
           CourseClass.find("MAD"),
           Professor.find("Mr. Waseem"),
           Group.find("D21"),
           CourseClass.find("CC"),
           Professor.find("Dr. Talha Waheed"),
           Group.find("A20"),
           CourseClass.find("CC"),
           Professor.find("Dr. Talha Waheed"),
           Group.find("B20"),
           CourseClass.find("CC"),
           Professor.find("Dr. Talha Waheed"),
           Group.find("C20"),
           CourseClass.find("CC (Lab)"),
           Professor.find("Ms. Aaliya"),
           Group.find("A20"),
           CourseClass.find("CC (Lab)"),
           Professor.find("Ms. Aaliya"),
           Group.find("B20"),
           CourseClass.find("CC (Lab)"),
           Professor.find("Ms. Aaliya"),
           Group.find("C20"),
           CourseClass.find("NLP"),
           Professor.find("Dr. Usman Ghani"),
           Group.find("A20"),
           CourseClass.find("NLP"),
           Professor.find("Dr. Usman Ghani"),
           Group.find("B20"),
           CourseClass.find("NLP"),
           Professor.find("Dr. Usman Ghani"),
           Group.find("C20"),
           CourseClass.find("IPS"),
           Professor.find("Department of Islamic Studies"),
           Group.find("A20"),
           CourseClass.find("IPS"),
           Professor.find("Department of Islamic Studies"),
           Group.find("B20"),
           CourseClass.find("IPS"),
           Professor.find("Department of Islamic Studies"),
           Group.find("C20"),
           CourseClass.find("IR"),
           Professor.find("Dr. Khaldoon"),
           Group.find("A20"),
           CourseClass.find("IR"),
           Professor.find("Dr. Khaldoon"),
           Group.find("B20"),
           CourseClass.find("IR"),
           Professor.find("Dr. Khaldoon"),
           Group.find("C20"),
           CourseClass.find("CCom"),
           Professor.find("Nauman Shafee"),
           Group.find("A20"),
           CourseClass.find("CCom"),
           Professor.find("Nauman Shafee"),
           Group.find("B20"),
           CourseClass.find("CCom"),
           Professor.find("Nauman Shafee"),
           Group.find("C20"),

           ]

    for _c in range(len(cpg)):
        if (_c == 48):
            print("yes")
        if _c % 3 == 0:
            cpg[_c] = (bin(cpg[_c])[2:]).rjust(
                bits_needed(CourseClass.classes), '0')
        elif _c % 3 == 1:  # Professor
            cpg[_c] = (bin(cpg[_c])[2:]).rjust(
                bits_needed(Professor.professors), '0')
        else:  # Group
            cpg[_c] = (bin(cpg[_c])[2:]).rjust(bits_needed(Group.groups), '0')
    cpg = join_cpg_pair(cpg)
    print(cpg)
    for r in range(len(Room.rooms)):
        lts.append((bin(r)[2:]).rjust(bits_needed(Room.rooms), '0'))

    for t in range(len(Slot.slots)):
        slots.append((bin(t)[2:]).rjust(bits_needed(Slot.slots), '0'))

    # print(cpg)
    max_score = (len(cpg) - 1) * 3 + len(cpg) * 3


def course_bits(chromosome):
    i = 0

    return chromosome[i:i + bits_needed(CourseClass.classes)]


def professor_bits(chromosome):
    i = bits_needed(CourseClass.classes)

    return chromosome[i: i + bits_needed(Professor.professors)]


def group_bits(chromosome):
    i = bits_needed(CourseClass.classes) + bits_needed(Professor.professors)

    return chromosome[i:i + bits_needed(Group.groups)]


def slot_bits(chromosome):
    i = bits_needed(CourseClass.classes) + bits_needed(Professor.professors) + \
        bits_needed(Group.groups)

    return chromosome[i:i + bits_needed(Slot.slots)]


def lt_bits(chromosome):
    i = bits_needed(CourseClass.classes) + bits_needed(Professor.professors) + \
        bits_needed(Group.groups) + bits_needed(Slot.slots)

    return chromosome[i: i + bits_needed(Room.rooms)]


def slot_clash(a, b):
    if slot_bits(a) == slot_bits(b):
        return 1
    return 0


# checks that a faculty member teaches only one course at a time.
def faculty_member_one_class(chromosome):
    scores = 0
    for i in range(len(chromosome) - 1):  # select one cpg pair
        clash = False
        for j in range(i + 1, len(chromosome)):  # check it with all other cpg pairs
            if slot_clash(chromosome[i], chromosome[j])\
                    and professor_bits(chromosome[i]) == professor_bits(chromosome[j]):
                clash = True
                # print("These prof. have clashes")
                # print_chromosome(chromosome[i])
                # print_chromosome(chromosome[j])
        if not clash:
            scores = scores + 1
    return scores


# check that a group member takes only one class at a time.
def group_member_one_class(chromosomes):
    scores = 0

    for i in range(len(chromosomes) - 1):
        clash = False
        for j in range(i + 1, len(chromosomes)):
            if slot_clash(chromosomes[i], chromosomes[j]) and\
                    group_bits(chromosomes[i]) == group_bits(chromosomes[j]):
                # print("These classes have slot/lts clash")
                # print_chromosome(chromosomes[i])
                # print_chromosome(chromosomes[j])
                # print("____________")
                clash = True
                break
        if not clash:
            # print("These classes have no slot/lts clash")
            # print_chromosome(chromosomes[i])
            # print_chromosome(chromosomes[j])
            # print("____________")
            scores = scores + 1
    return scores


# checks that a course is assigned to an available classroom.
def use_spare_classroom(chromosome):
    scores = 0
    for i in range(len(chromosome) - 1):  # select one cpg pair
        clash = False
        for j in range(i + 1, len(chromosome)):  # check it with all other cpg pairs
            if slot_clash(chromosome[i], chromosome[j]) and lt_bits(chromosome[i]) == lt_bits(chromosome[j]):
                # print("These classes have slot/lts clash")
                # printChromosome(chromosome[i])
                # printChromosome(chromosome[j])
                clash = True
        if not clash:
            scores = scores + 1
    return scores


# checks that the classroom capacity is large enough for the classes that
# are assigned to that classroom.
def classroom_size(chromosomes):
    scores = 0
    for _c in chromosomes:
        if Group.groups[int(group_bits(_c), 2)].size <= Room.rooms[int(lt_bits(_c), 2)].size:
            scores = scores + 1
    return scores


# check that room is appropriate for particular class/lab
def appropriate_room(chromosomes):
    scores = 0
    for _c in chromosomes:
        if CourseClass.classes[int(course_bits(_c), 2)].is_lab == Room.rooms[int(lt_bits(_c), 2)].is_lab:
            scores = scores + 1
    return scores


# check that lab is allocated appropriate time slot
def appropriate_timeslot(chromosomes):
    scores = 0
    for _c in chromosomes:
        if CourseClass.classes[int(course_bits(_c), 2)].is_lab == Slot.slots[int(slot_bits(_c), 2)].is_lab_slot:
            scores = scores + 1
    return scores


def evaluate(chromosomes):
    global max_score
    score = 0
    score = score + use_spare_classroom(chromosomes)
    score = score + faculty_member_one_class(chromosomes)
    score = score + classroom_size(chromosomes)
    score = score + group_member_one_class(chromosomes)
    score = score + appropriate_room(chromosomes)
    score = score + appropriate_timeslot(chromosomes)
    return score / max_score


def cost(solution):
    # solution would be an array inside an array
    # it is because we use it as it is in genetic algorithms
    # too. Because, GA require multiple solutions i.e population
    # to work.
    return 1 / float(evaluate(solution))


def init_population(n):
    global cpg, lts, slots
    chromosomes = []
    for _n in range(n):
        chromosome = []
        for _c in cpg:
            chromosome.append(_c + random.choice(slots) + random.choice(lts))
        chromosomes.append(chromosome)
    return chromosomes


# Modified Combination of Row_reselect, Column_reselect
def mutate(chromosome):
    # print("Before mutation: ", end="")
    # printChromosome(chromosome)

    rand_slot = random.choice(slots)
    rand_lt = random.choice(lts)

    a = random.randint(0, len(chromosome) - 1)

    chromosome[a] = course_bits(chromosome[a]) + professor_bits(chromosome[a]) +\
        group_bits(chromosome[a]) + rand_slot + rand_lt

    # print("After mutation: ", end="")
    # printChromosome(chromosome)


def crossover(population):
    a = random.randint(0, len(population) - 1)
    b = random.randint(0, len(population) - 1)
    # assume all chromosome are of same len
    cut = random.randint(0, len(population[0]))
    population.append(population[a][:cut] + population[b][cut:])


def selection(population, n):
    population.sort(key=evaluate, reverse=True)
    while len(population) > n:
        population.pop()


def print_chromosome(chromosome):
    print(CourseClass.classes[int(course_bits(chromosome), 2)], " | ",
          Professor.professors[int(professor_bits(chromosome), 2)], " | ",
          Group.groups[int(group_bits(chromosome), 2)], " | ",
          Slot.slots[int(slot_bits(chromosome), 2)], " | ",
          Room.rooms[int(lt_bits(chromosome), 2)])


def toJson(chromosome):
    global Schedule
    classname = CourseClass.classes[int(course_bits(chromosome), 2)]
    prof = Professor.professors[int(professor_bits(chromosome), 2)]
    section = Group.groups[int(group_bits(chromosome), 2)],
    time = Slot.slots[int(slot_bits(chromosome), 2)],
    room = Room.rooms[int(lt_bits(chromosome), 2)]
    Schedule.setdefault(section[0].name, {})
    Schedule[section[0].name].setdefault(time[0].day, {})
    Schedule[section[0].name][time[0]
                              .day][f"{time[0].start}-{time[0].end}"] = f"{classname.code} {room.name}"


def print_schedule():
    global Schedule

    table = []
    for key, value in Schedule.items():
        slots = sorted(
            set(f"{slot.start}-{slot.end}" for slot in Slot.slots))
        headers = ["Day\\Slot"] + slots

        custom_day_order = ["Mon", "Tue", "Wed", "Thu", "Fri"]

        days = sorted(set(f"{slot.day}" for slot in Slot.slots),
                      key=lambda x: custom_day_order.index(x))
        table = [headers]

        for day in days:
            row = [day]
            for slot in slots:
                row.append(f"-")
            table.append(row)

        print(key)
        print(value)
        for day, slotsOfDay in value.items():
            day_idx = days.index(day)
            if (day_idx == 0):
                print("yes")
            for slot, details in slotsOfDay.items():
                slot_idx = slots.index(slot)
                if (slot_idx == 0):
                    print("yes")
                table[day_idx+1][slot_idx+1] = details
            # print(day)
            # print(slots)
            # row = [day]
            # slot_info = [
            #     f"{info.split(': ')[1]}" for slot, info in slots.items()]
            # row.extend(slot_info)
        # table.append(row)
        print(tabulate(table, tablefmt="grid"))


# Simple Searching Neighborhood
# It randomly changes timeslot of a class/lab


def ssn(solution):
    rand_slot = random.choice(slots)
    rand_lt = random.choice(lts)

    a = random.randint(0, len(solution) - 1)

    new_solution = copy.deepcopy(solution)
    new_solution[a] = course_bits(solution[a]) + professor_bits(solution[a]) +\
        group_bits(solution[a]) + rand_slot + lt_bits(solution[a])
    return [new_solution]

# Swapping Neighborhoods
# It randomy selects two classes and swap their time slots


def swn(solution):
    a = random.randint(0, len(solution) - 1)
    b = random.randint(0, len(solution) - 1)
    new_solution = copy.deepcopy(solution)
    temp = slot_bits(solution[a])
    new_solution[a] = course_bits(solution[a]) + professor_bits(solution[a]) +\
        group_bits(solution[a]) + slot_bits(solution[b]) + lt_bits(solution[a])

    new_solution[b] = course_bits(solution[b]) + professor_bits(solution[b]) +\
        group_bits(solution[b]) + temp + lt_bits(solution[b])
    # print("Diff", solution)
    # print("Meiw", new_solution)
    return [new_solution]


def acceptance_probability(old_cost, new_cost, temperature):
    if new_cost < old_cost:
        return 1.0
    else:
        return math.exp((old_cost - new_cost) / temperature)


def simulated_annealing():
    alpha = 0.9
    T = 1.0
    T_min = 0.00001

    convert_input_to_bin()
    # as simulated annealing is a single-state method
    population = init_population(1)
    old_cost = cost(population[0])
    # print("Cost of original random solution: ", old_cost)
    # print("Original population:")
    # print(population)

    for __n in range(500):
        new_solution = swn(population[0])
        new_solution = ssn(population[0])
        new_cost = cost(new_solution[0])
        ap = acceptance_probability(old_cost, new_cost, T)
        if ap > random.random():
            population = new_solution
            old_cost = new_cost
        T = T * alpha
    # print(population)
    # print("Cost of altered solution: ", cost(population[0]))
    print("\n------------- Simulated Annealing --------------\n")
    for lec in population[0]:
        print_chromosome(lec)
    print("Score: ", evaluate(population[0]))


def genetic_algorithm():
    start_time = time.time()
    generation = 0
    convert_input_to_bin()
    population = init_population(3)

    # print("Original population:")
    # print(population)
    print("\n------------- Genetic Algorithm --------------\n")
    i = 0
    while True:
        print(f"GA {generation}")
        # if termination criteria are satisfied, stop.
        if evaluate(max(population, key=evaluate)) == 1 or generation == 500:
            print("Generations:", generation)
            print("Best Chromosome fitness value",
                  evaluate(max(population, key=evaluate)))
            print("Best Chromosome: ", max(population, key=evaluate))
            for lec in max(population, key=evaluate):

                print_chromosome(lec)
                toJson(lec)
            global Schedule
            # print(Schedule)
            print_schedule()
            break

        # Otherwise continue
        else:
            for _c in range(len(population)):
                crossover(population)
                selection(population, 5)

                # selection(population[_c], len(cpg))
                mutate(population[_c])

        generation = generation + 1
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(
        f"start ={start_time} end= {end_time} Elapsed Time: {elapsed_time} seconds")
    # print("Gen: ", generation)

    # print("Population", len(population))


def main():
    random.seed()
    genetic_algorithm()
    simulated_annealing()


main()
# Out:
# yes
# ['101010110011011', '101010110011100', '101010011111101', '101010110101110', '101100110101011', '101100110101100', '101100110101101', '101100110101110', '110000111001011', '110000111001100', '110000111011101', '110000111011110', '110010111001011', '110010111001100', '110010111011101', '110010111011110', '110100111101011', '110100111101100', '110100111101101', '110100111101110', '110110111111011', '110110111111100', '110110111111101', '110110111111110', '111001000001011', '111001000001100', '111001000001101', '111001000001110', '111011000011011', '111011000011100', '111011000011101', '111011000011110', '011100100100111', '011100100101000', '011100100111001', '011100100111010', '011110100100111', '011110100101000', '011110100111001', '011110100111010', '100000101000111', '100000101001000', '100000101001001', '100000101001010', '100010101010111', '100010101011000', '100010101011001', '100010101101010', '100100101100111', '100100101101000', '100100101101001', '100100101101010', '100110101110111', '100110101111000', '100110101111001', '100110101111010', '101000110000111', '101000110001000', '101000110001001', '101000110001010', '001100001100011', '001100001100100', '001100001100101', '001100001110110', '001110001110011', '001110001110100', '001110001110101', '001110001110110', '010000010010100', '010000010100011', '010000010100101', '010010010110011', '010010010110100', '010010010110101', '010010010110110', '010100011000011', '010100011000100', '010100011000101', '010100011000110', '010110011010011', '010110011010100', '010110011100101', '010110011100110', '011000011110011', '011000011110100', '011000011110101', '011000011110110', '011010100000011', '011010100000100', '011010100000101', '011010100010110', '000000000000000', '000000000000001', '000000000000010', '000010000010000', '000010000010001', '000010000010010', '000100000100000', '000100000100001', '000100000100010', '000110000110000', '000110000110001', '000110000110010', '001000001000000', '001000001000001', '001000001000010', '001010001010000', '001010001010001', '001010001010010']
#
# ------------- Genetic Algorithm --------------
#
# GA 0
# GA 1
# GA 2
# GA 3
# GA 4
# GA 5
# GA 6
# GA 7
# GA 8
# GA 9
# GA 10
# GA 11
# GA 12
# GA 13
# GA 14
# GA 15
# GA 16
# GA 17
# GA 18
# GA 19
# GA 20
# GA 21
# GA 22
# GA 23
# GA 24
# GA 25
# GA 26
# GA 27
# GA 28
# GA 29
# GA 30
# GA 31
# GA 32
# GA 33
# GA 34
# GA 35
# GA 36
# GA 37
# GA 38
# GA 39
# GA 40
# GA 41
# GA 42
# GA 43
# GA 44
# GA 45
# GA 46
# GA 47
# GA 48
# GA 49
# GA 50
# GA 51
# GA 52
# GA 53
# GA 54
# GA 55
# GA 56
# GA 57
# GA 58
# GA 59
# GA 60
# GA 61
# GA 62
# GA 63
# GA 64
# GA 65
# GA 66
# GA 67
# GA 68
# GA 69
# GA 70
# GA 71
# GA 72
# GA 73
# GA 74
# GA 75
# GA 76
# GA 77
# GA 78
# GA 79
# GA 80
# GA 81
# GA 82
# GA 83
# GA 84
# GA 85
# GA 86
# GA 87
# GA 88
# GA 89
# GA 90
# GA 91
# GA 92
# GA 93
# GA 94
# GA 95
# GA 96
# GA 97
# GA 98
# GA 99
# GA 100
# GA 101
# GA 102
# GA 103
# GA 104
# GA 105
# GA 106
# GA 107
# GA 108
# GA 109
# GA 110
# GA 111
# GA 112
# GA 113
# GA 114
# GA 115
# GA 116
# GA 117
# GA 118
# GA 119
# GA 120
# GA 121
# GA 122
# GA 123
# GA 124
# GA 125
# GA 126
# GA 127
# GA 128
# GA 129
# GA 130
# GA 131
# GA 132
# GA 133
# GA 134
# GA 135
# GA 136
# GA 137
# GA 138
# GA 139
# GA 140
# GA 141
# GA 142
# GA 143
# GA 144
# GA 145
# GA 146
# GA 147
# GA 148
# GA 149
# GA 150
# GA 151
# GA 152
# GA 153
# GA 154
# GA 155
# GA 156
# GA 157
# GA 158
# GA 159
# GA 160
# GA 161
# GA 162
# GA 163
# GA 164
# GA 165
# GA 166
# GA 167
# GA 168
# GA 169
# GA 170
# GA 171
# GA 172
# GA 173
# GA 174
# GA 175
# GA 176
# GA 177
# GA 178
# GA 179
# GA 180
# GA 181
# GA 182
# GA 183
# GA 184
# GA 185
# GA 186
# GA 187
# GA 188
# GA 189
# GA 190
# GA 191
# GA 192
# GA 193
# GA 194
# GA 195
# GA 196
# GA 197
# GA 198
# GA 199
# GA 200
# GA 201
# GA 202
# GA 203
# GA 204
# GA 205
# GA 206
# GA 207
# GA 208
# GA 209
# GA 210
# GA 211
# GA 212
# GA 213
# GA 214
# GA 215
# GA 216
# GA 217
# GA 218
# GA 219
# GA 220
# GA 221
# GA 222
# GA 223
# GA 224
# GA 225
# GA 226
# GA 227
# GA 228
# GA 229
# GA 230
# GA 231
# GA 232
# GA 233
# GA 234
# GA 235
# GA 236
# GA 237
# GA 238
# GA 239
# GA 240
# GA 241
# GA 242
# GA 243
# GA 244
# GA 245
# GA 246
# GA 247
# GA 248
# GA 249
# GA 250
# GA 251
# GA 252
# GA 253
# GA 254
# GA 255
# GA 256
# GA 257
# GA 258
# GA 259
# GA 260
# GA 261
# GA 262
# GA 263
# GA 264
# GA 265
# GA 266
# GA 267
# GA 268
# GA 269
# GA 270
# GA 271
# GA 272
# GA 273
# GA 274
# GA 275
# GA 276
# GA 277
# GA 278
# GA 279
# GA 280
# GA 281
# GA 282
# GA 283
# GA 284
# GA 285
# GA 286
# GA 287
# GA 288
# GA 289
# GA 290
# GA 291
# GA 292
# GA 293
# GA 294
# GA 295
# GA 296
# GA 297
# GA 298
# GA 299
# GA 300
# GA 301
# GA 302
# GA 303
# GA 304
# GA 305
# GA 306
# GA 307
# GA 308
# GA 309
# GA 310
# GA 311
# GA 312
# GA 313
# GA 314
# GA 315
# GA 316
# GA 317
# GA 318
# GA 319
# GA 320
# GA 321
# GA 322
# GA 323
# GA 324
# GA 325
# GA 326
# GA 327
# GA 328
# GA 329
# GA 330
# GA 331
# GA 332
# GA 333
# GA 334
# GA 335
# GA 336
# GA 337
# GA 338
# GA 339
# GA 340
# GA 341
# GA 342
# GA 343
# GA 344
# GA 345
# GA 346
# GA 347
# GA 348
# GA 349
# GA 350
# GA 351
# GA 352
# GA 353
# GA 354
# GA 355
# GA 356
# GA 357
# GA 358
# GA 359
# GA 360
# GA 361
# GA 362
# GA 363
# GA 364
# GA 365
# GA 366
# GA 367
# GA 368
# GA 369
# GA 370
# GA 371
# GA 372
# GA 373
# GA 374
# GA 375
# GA 376
# GA 377
# GA 378
# GA 379
# GA 380
# GA 381
# GA 382
# GA 383
# GA 384
# GA 385
# GA 386
# GA 387
# GA 388
# GA 389
# GA 390
# GA 391
# GA 392
# GA 393
# GA 394
# GA 395
# GA 396
# GA 397
# GA 398
# GA 399
# GA 400
# GA 401
# GA 402
# GA 403
# GA 404
# GA 405
# GA 406
# GA 407
# GA 408
# GA 409
# GA 410
# GA 411
# GA 412
# GA 413
# GA 414
# GA 415
# GA 416
# GA 417
# GA 418
# GA 419
# GA 420
# GA 421
# GA 422
# GA 423
# GA 424
# GA 425
# GA 426
# GA 427
# GA 428
# GA 429
# GA 430
# GA 431
# GA 432
# GA 433
# GA 434
# GA 435
# GA 436
# GA 437
# GA 438
# GA 439
# GA 440
# GA 441
# GA 442
# GA 443
# GA 444
# GA 445
# GA 446
# GA 447
# GA 448
# GA 449
# GA 450
# GA 451
# GA 452
# GA 453
# GA 454
# GA 455
# GA 456
# GA 457
# GA 458
# GA 459
# GA 460
# GA 461
# GA 462
# GA 463
# GA 464
# GA 465
# GA 466
# GA 467
# GA 468
# GA 469
# GA 470
# GA 471
# GA 472
# GA 473
# GA 474
# GA 475
# GA 476
# GA 477
# GA 478
# GA 479
# GA 480
# GA 481
# GA 482
# GA 483
# GA 484
# GA 485
# GA 486
# GA 487
# GA 488
# GA 489
# GA 490
# GA 491
# GA 492
# GA 493
# GA 494
# GA 495
# GA 496
# GA 497
# GA 498
# GA 499
# GA 500
# Generations: 500
# Best Chromosome fitness value 0.9539170506912442
# Best Chromosome:  ['1010101100110110111010110', '1010101100111000011000011', '1010100111111010111110001', '1010101101011100011000110', '1011001101010110001111101', '1011001101011000000011100', '1011001101011011000101111', '1011001101011100100111100', '1100001110010110001100101', '1100001110011000111110111', '1100001110111010000100101', '1100001110111101000000110', '1100101110010110110000101', '1100101110011000010000011', '1100101110111010001110010', '1100101110111100010100100', '1101001111010110011100101', '1101001111011001000010100', '1101001111011010000110011', '1101001111011101000100100', '1101101111110111000011000', '1101101111111000010111001', '1101101111111010100101011', '1101101111111100001110101', '1110010000010110000010011', '1110010000011000000111010', '1110010000011010100110010', '1110010000011100110011011', '1110110000110110011010111', '1110110000111000111101001', '1110110000111011000010111', '1110110000111100011111001', '0111001001001110010010110', '0111001001010000001011001', '0111001001110011000001001', '0111001001110100100110100', '0111101001001111000011101', '0111101001010000011101101', '0111101001110010011001100', '0111101001110100001101110', '1000001010001110011000100', '1000001010010000010111011', '1000001010010010111101011', '1000001010010100011110110', '1000101010101110001010001', '1000101010110001000000101', '1000101010110010010110000', '1000101011010100101100110', '1001001011001111000101001', '1001001011010000111101101', '1001001011010010110101010', '1001001011010100111011101', '1001101011101110101100010', '1001101011110000110111000', '1001101011110011000100110', '1001101011110100101111011', '1010001100001110110011000', '1010001100010000001101000', '1010001100010010101001001', '1010001100010101000000010', '0011000011000110110001001', '0011000011001000100010100', '0011000011001010100101010', '0011000011101100000001011', '0011100011100110111111101', '0011100011101000000011111', '0011100011101010011011100', '0011100011101100011101111', '0100000100101000111100000', '0100000101000110010001000', '0100000101001011000001010', '0100100101100110110111100', '0100100101101000001111100', '0100100101101010010011110', '0100100101101100000010101', '0101000110000110010111010', '0101000110001000010101000', '0101000110001011000010000', '0101000110001100110101001', '0101100110100111000000111', '0101100110101000110100101', '0101100111001010001010010', '0101100111001100101100101', '0110000111100110011011111', '0110000111101000100001111', '0110000111101010001001110', '0110000111101100101001100', '0110101000000110111000000', '0110101000001001000001000', '0110101000001010101011000', '0110101000101100100100001', '0000000000000000101010111', '0000000000000010011100011', '0000000000000100010010100', '0000100000100001000011111', '0000100000100010011111100', '0000100000100100001011110', '0001000001000000010010101', '0001000001000010001110110', '0001000001000100100010111', '0001100001100000010110101', '0001100001100010110110010', '0001100001100100101001011', '0010000010000000011000101', '0010000010000010101010110', '0010000010000100000010110', '0010100010100000000001000', '0010100010100010011010010', '0010100010100100101100100']
# CourseClass: PF  |  Professor: Dr. Awais Hassan  |  Group: A23, Size: 43  |  Slot: 09:00-10:00 Day: Fri  |  Room: N7 Size: 60
# CourseClass: PF  |  Professor: Dr. Awais Hassan  |  Group: B23, Size: 50  |  Slot: 14:00-15:00 Day: Tue  |  Room: N4 Size: 60
# CourseClass: PF  |  Professor: Mr. Laeeq uz Zaman  |  Group: C23, Size: 30  |  Slot: 11:00-12:00 Day: Fri  |  Room: N2 Size: 60
# CourseClass: PF  |  Professor: Ms. Maida  |  Group: D23, Size: 43  |  Slot: 14:00-15:00 Day: Tue  |  Room: N7 Size: 60
# CourseClass: PF (Lab)  |  Professor: Ms. Maida  |  Group: A23, Size: 43  |  Slot: 08:00-09:00 Day: Tue  |  Room: lab2 Size: 60
# CourseClass: PF (Lab)  |  Professor: Ms. Maida  |  Group: B23, Size: 50  |  Slot: 09:00-10:00 Day: Mon  |  Room: lab1 Size: 60
# CourseClass: PF (Lab)  |  Professor: Ms. Maida  |  Group: C23, Size: 30  |  Slot: 15:00-16:00 Day: Fri  |  Room: lab4 Size: 60
# CourseClass: PF (Lab)  |  Professor: Ms. Maida  |  Group: D23, Size: 43  |  Slot: 14:00-15:00 Day: Wed  |  Room: lab1 Size: 60
# CourseClass: AICT  |  Professor: Ms. Abqa Javed  |  Group: A23, Size: 43  |  Slot: 15:00-16:00 Day: Mon  |  Room: N6 Size: 60
# CourseClass: AICT  |  Professor: Ms. Abqa Javed  |  Group: B23, Size: 50  |  Slot: 11:00-12:00 Day: Fri  |  Room: N8 Size: 60
# CourseClass: AICT  |  Professor: Dr. Amna Zafar  |  Group: C23, Size: 30  |  Slot: 10:00-11:00 Day: Mon  |  Room: N6 Size: 60
# CourseClass: AICT  |  Professor: Dr. Amna Zafar  |  Group: D23, Size: 43  |  Slot: 13:00-14:00 Day: Fri  |  Room: N7 Size: 60
# CourseClass: AICT (Lab)  |  Professor: Ms. Abqa Javed  |  Group: A23, Size: 43  |  Slot: 11:00-12:00 Day: Thu  |  Room: N6 Size: 60
# CourseClass: AICT (Lab)  |  Professor: Ms. Abqa Javed  |  Group: B23, Size: 50  |  Slot: 09:00-10:00 Day: Tue  |  Room: N4 Size: 60
# CourseClass: AICT (Lab)  |  Professor: Dr. Amna Zafar  |  Group: C23, Size: 30  |  Slot: 08:00-09:00 Day: Tue  |  Room: N3 Size: 60
# CourseClass: AICT (Lab)  |  Professor: Dr. Amna Zafar  |  Group: D23, Size: 43  |  Slot: 11:00-12:00 Day: Tue  |  Room: N5 Size: 60
# CourseClass: DMI  |  Professor: Waqas Ali  |  Group: A23, Size: 43  |  Slot: 08:00-09:00 Day: Wed  |  Room: N6 Size: 60
# CourseClass: DMI  |  Professor: Waqas Ali  |  Group: B23, Size: 50  |  Slot: 14:00-15:00 Day: Fri  |  Room: N5 Size: 60
# CourseClass: DMI  |  Professor: Waqas Ali  |  Group: C23, Size: 30  |  Slot: 11:00-12:00 Day: Mon  |  Room: N4 Size: 60
# CourseClass: DMI  |  Professor: Waqas Ali  |  Group: D23, Size: 43  |  Slot: 15:00-16:00 Day: Fri  |  Room: N5 Size: 60
# CourseClass: FE  |  Professor: Humanities Department I  |  Group: A23, Size: 43  |  Slot: 14:00-15:00 Day: Fri  |  Room: N9 Size: 60
# CourseClass: FE  |  Professor: Humanities Department I  |  Group: B23, Size: 50  |  Slot: 13:00-14:00 Day: Tue  |  Room: N10 Size: 60
# CourseClass: FE  |  Professor: Humanities Department I  |  Group: C23, Size: 30  |  Slot: 13:00-14:00 Day: Wed  |  Room: N12 Size: 60
# CourseClass: FE  |  Professor: Humanities Department I  |  Group: D23, Size: 43  |  Slot: 08:00-09:00 Day: Tue  |  Room: N6 Size: 60
# CourseClass: C  |  Professor: Mathematics Department I  |  Group: A23, Size: 43  |  Slot: 09:00-10:00 Day: Mon  |  Room: N4 Size: 60
# CourseClass: C  |  Professor: Mathematics Department I  |  Group: B23, Size: 50  |  Slot: 11:00-12:00 Day: Mon  |  Room: N11 Size: 60
# CourseClass: C  |  Professor: Mathematics Department I  |  Group: C23, Size: 30  |  Slot: 14:00-15:00 Day: Wed  |  Room: N3 Size: 60
# CourseClass: C  |  Professor: Mathematics Department I  |  Group: D23, Size: 43  |  Slot: 13:00-14:00 Day: Thu  |  Room: N12 Size: 60
# CourseClass: WP  |  Professor: Mechanical Department I  |  Group: A23, Size: 43  |  Slot: 15:00-16:00 Day: Tue  |  Room: N8 Size: 60
# CourseClass: WP  |  Professor: Mechanical Department I  |  Group: B23, Size: 50  |  Slot: 10:00-11:00 Day: Fri  |  Room: N10 Size: 60
# CourseClass: WP  |  Professor: Mechanical Department I  |  Group: C23, Size: 30  |  Slot: 14:00-15:00 Day: Fri  |  Room: N8 Size: 60
# CourseClass: WP  |  Professor: Mechanical Department I  |  Group: D23, Size: 43  |  Slot: 09:00-10:00 Day: Wed  |  Room: N10 Size: 60
# CourseClass: DSA  |  Professor: Mr. Nazeef ul Haq  |  Group: A22, Size: 43  |  Slot: 10:00-11:00 Day: Tue  |  Room: N7 Size: 60
# CourseClass: DSA  |  Professor: Mr. Nazeef ul Haq  |  Group: B22, Size: 50  |  Slot: 14:00-15:00 Day: Mon  |  Room: N10 Size: 60
# CourseClass: DSA  |  Professor: Mr. Faraz  |  Group: C22, Size: 30  |  Slot: 13:00-14:00 Day: Fri  |  Room: N10 Size: 60
# CourseClass: DSA  |  Professor: Mr. Faraz  |  Group: D22, Size: 43  |  Slot: 14:00-15:00 Day: Wed  |  Room: N5 Size: 60
# CourseClass: DSA (Lab)  |  Professor: Mr. Nazeef ul Haq  |  Group: A22, Size: 43  |  Slot: 14:00-15:00 Day: Fri  |  Room: lab2 Size: 60
# CourseClass: DSA (Lab)  |  Professor: Mr. Nazeef ul Haq  |  Group: B22, Size: 50  |  Slot: 08:00-09:00 Day: Wed  |  Room: lab2 Size: 60
# CourseClass: DSA (Lab)  |  Professor: Mr. Faraz  |  Group: C22, Size: 30  |  Slot: 14:00-15:00 Day: Tue  |  Room: lab1 Size: 60
# CourseClass: DSA (Lab)  |  Professor: Mr. Faraz  |  Group: D22, Size: 43  |  Slot: 15:00-16:00 Day: Mon  |  Room: lab3 Size: 60
# CourseClass: TW  |  Professor: Humanities Department II  |  Group: A22, Size: 43  |  Slot: 14:00-15:00 Day: Tue  |  Room: N5 Size: 60
# CourseClass: TW  |  Professor: Humanities Department II  |  Group: B22, Size: 50  |  Slot: 13:00-14:00 Day: Tue  |  Room: N12 Size: 60
# CourseClass: TW  |  Professor: Humanities Department II  |  Group: C22, Size: 30  |  Slot: 10:00-11:00 Day: Fri  |  Room: N12 Size: 60
# CourseClass: TW  |  Professor: Humanities Department II  |  Group: D22, Size: 43  |  Slot: 09:00-10:00 Day: Wed  |  Room: N7 Size: 60
# CourseClass: COAL  |  Professor: Mr. Tauqir Ahmed  |  Group: A22, Size: 43  |  Slot: 14:00-15:00 Day: Mon  |  Room: N2 Size: 60
# CourseClass: COAL  |  Professor: Mr. Tauqir Ahmed  |  Group: B22, Size: 50  |  Slot: 13:00-14:00 Day: Fri  |  Room: N6 Size: 60
# CourseClass: COAL  |  Professor: Mr. Tauqir Ahmed  |  Group: C22, Size: 30  |  Slot: 13:00-14:00 Day: Tue  |  Room: N1 Size: 60
# CourseClass: COAL  |  Professor: Mr. Tehseen  |  Group: D22, Size: 43  |  Slot: 09:00-10:00 Day: Thu  |  Room: N7 Size: 60
# CourseClass: COAL (Lab)  |  Professor: Mr. Tehseen  |  Group: A22, Size: 43  |  Slot: 15:00-16:00 Day: Fri  |  Room: N10 Size: 60
# CourseClass: COAL (Lab)  |  Professor: Mr. Tehseen  |  Group: B22, Size: 50  |  Slot: 10:00-11:00 Day: Fri  |  Room: lab2 Size: 60
# CourseClass: COAL (Lab)  |  Professor: Mr. Tehseen  |  Group: C22, Size: 30  |  Slot: 14:00-15:00 Day: Thu  |  Room: N11 Size: 60
# CourseClass: COAL (Lab)  |  Professor: Mr. Tehseen  |  Group: D22, Size: 43  |  Slot: 09:00-10:00 Day: Fri  |  Room: lab2 Size: 60
# CourseClass: LA  |  Professor: Mathematics Department II  |  Group: A22, Size: 43  |  Slot: 09:00-10:00 Day: Thu  |  Room: N3 Size: 60
# CourseClass: LA  |  Professor: Mathematics Department II  |  Group: B22, Size: 50  |  Slot: 15:00-16:00 Day: Thu  |  Room: N9 Size: 60
# CourseClass: LA  |  Professor: Mathematics Department II  |  Group: C22, Size: 30  |  Slot: 15:00-16:00 Day: Fri  |  Room: N7 Size: 60
# CourseClass: LA  |  Professor: Mathematics Department II  |  Group: D22, Size: 43  |  Slot: 10:00-11:00 Day: Thu  |  Room: N12 Size: 60
# CourseClass: DMII  |  Professor: Dr. Ayesha Altaf  |  Group: A22, Size: 43  |  Slot: 13:00-14:00 Day: Thu  |  Room: N9 Size: 60
# CourseClass: DMII  |  Professor: Dr. Ayesha Altaf  |  Group: B22, Size: 50  |  Slot: 15:00-16:00 Day: Mon  |  Room: N9 Size: 60
# CourseClass: DMII  |  Professor: Dr. Ayesha Altaf  |  Group: C22, Size: 30  |  Slot: 15:00-16:00 Day: Wed  |  Room: N10 Size: 60
# CourseClass: DMII  |  Professor: Dr. Ayesha Altaf  |  Group: D22, Size: 43  |  Slot: 13:00-14:00 Day: Fri  |  Room: N3 Size: 60
# CourseClass: CN  |  Professor: Dr. Junaid Arshad  |  Group: A21, Size: 43  |  Slot: 11:00-12:00 Day: Thu  |  Room: N10 Size: 60
# CourseClass: CN  |  Professor: Dr. Junaid Arshad  |  Group: B21, Size: 50  |  Slot: 11:00-12:00 Day: Wed  |  Room: N5 Size: 60
# CourseClass: CN  |  Professor: Dr. Junaid Arshad  |  Group: C21, Size: 30  |  Slot: 13:00-14:00 Day: Wed  |  Room: N11 Size: 60
# CourseClass: CN  |  Professor: Ms. Aroosh  |  Group: D21, Size: 43  |  Slot: 08:00-09:00 Day: Mon  |  Room: N12 Size: 60
# CourseClass: CN (Lab)  |  Professor: Ms. Aroosh  |  Group: A21, Size: 43  |  Slot: 11:00-12:00 Day: Fri  |  Room: lab2 Size: 60
# CourseClass: CN (Lab)  |  Professor: Ms. Aroosh  |  Group: B21, Size: 50  |  Slot: 09:00-10:00 Day: Mon  |  Room: lab4 Size: 60
# CourseClass: CN (Lab)  |  Professor: Ms. Aroosh  |  Group: C21, Size: 30  |  Slot: 15:00-16:00 Day: Tue  |  Room: lab1 Size: 60
# CourseClass: CN (Lab)  |  Professor: Ms. Aroosh  |  Group: D21, Size: 43  |  Slot: 08:00-09:00 Day: Wed  |  Room: lab4 Size: 60
# CourseClass: AI  |  Professor: Prof. Dr. M. Aslam  |  Group: B21, Size: 50  |  Slot: 10:00-11:00 Day: Fri  |  Room: N1 Size: 60
# CourseClass: AI  |  Professor: Mr. Samyan Qayyum  |  Group: A21, Size: 43  |  Slot: 09:00-10:00 Day: Tue  |  Room: N9 Size: 60
# CourseClass: AI  |  Professor: Mr. Samyan Qayyum  |  Group: C21, Size: 30  |  Slot: 13:00-14:00 Day: Fri  |  Room: N11 Size: 60
# CourseClass: AI (Lab)  |  Professor: Ms. Tazeem  |  Group: A21, Size: 43  |  Slot: 15:00-16:00 Day: Thu  |  Room: lab1 Size: 60
# CourseClass: AI (Lab)  |  Professor: Ms. Tazeem  |  Group: B21, Size: 50  |  Slot: 08:00-09:00 Day: Tue  |  Room: lab1 Size: 60
# CourseClass: AI (Lab)  |  Professor: Ms. Tazeem  |  Group: C21, Size: 30  |  Slot: 10:00-11:00 Day: Tue  |  Room: lab3 Size: 60
# CourseClass: AI (Lab)  |  Professor: Ms. Tazeem  |  Group: D21, Size: 43  |  Slot: 09:00-10:00 Day: Mon  |  Room: N6 Size: 60
# CourseClass: PPSD  |  Professor: Dr. Faiza Iqbal  |  Group: A21, Size: 43  |  Slot: 13:00-14:00 Day: Tue  |  Room: N11 Size: 60
# CourseClass: PPSD  |  Professor: Dr. Faiza Iqbal  |  Group: B21, Size: 50  |  Slot: 11:00-12:00 Day: Tue  |  Room: N9 Size: 60
# CourseClass: PPSD  |  Professor: Dr. Faiza Iqbal  |  Group: C21, Size: 30  |  Slot: 14:00-15:00 Day: Fri  |  Room: N1 Size: 60
# CourseClass: PPSD  |  Professor: Dr. Faiza Iqbal  |  Group: D21, Size: 43  |  Slot: 14:00-15:00 Day: Thu  |  Room: N10 Size: 60
# CourseClass: SE  |  Professor: Mr. Aatif Hussain  |  Group: A21, Size: 43  |  Slot: 13:00-14:00 Day: Fri  |  Room: N8 Size: 60
# CourseClass: SE  |  Professor: Mr. Aatif Hussain  |  Group: B21, Size: 50  |  Slot: 14:00-15:00 Day: Thu  |  Room: N6 Size: 60
# CourseClass: SE  |  Professor: Prof. Dr. Shazia Arshad  |  Group: C21, Size: 30  |  Slot: 14:00-15:00 Day: Mon  |  Room: N3 Size: 60
# CourseClass: SE  |  Professor: Prof. Dr. Shazia Arshad  |  Group: D21, Size: 43  |  Slot: 09:00-10:00 Day: Thu  |  Room: N6 Size: 60
# CourseClass: SE (Lab)  |  Professor: Mr. Laeeq uz Zaman  |  Group: A21, Size: 43  |  Slot: 15:00-16:00 Day: Tue  |  Room: lab4 Size: 60
# CourseClass: SE (Lab)  |  Professor: Mr. Laeeq uz Zaman  |  Group: B21, Size: 50  |  Slot: 10:00-11:00 Day: Wed  |  Room: lab4 Size: 60
# CourseClass: SE (Lab)  |  Professor: Mr. Laeeq uz Zaman  |  Group: C21, Size: 30  |  Slot: 13:00-14:00 Day: Mon  |  Room: lab3 Size: 60
# CourseClass: SE (Lab)  |  Professor: Mr. Laeeq uz Zaman  |  Group: D21, Size: 43  |  Slot: 15:00-16:00 Day: Wed  |  Room: lab1 Size: 60
# CourseClass: MAD  |  Professor: Dr. Amjad Farooq  |  Group: A21, Size: 43  |  Slot: 08:00-09:00 Day: Fri  |  Room: N1 Size: 60
# CourseClass: MAD  |  Professor: Dr. Amjad Farooq  |  Group: B21, Size: 50  |  Slot: 13:00-14:00 Day: Fri  |  Room: N9 Size: 60
# CourseClass: MAD  |  Professor: Dr. Amjad Farooq  |  Group: C21, Size: 30  |  Slot: 08:00-09:00 Day: Thu  |  Room: N9 Size: 60
# CourseClass: MAD  |  Professor: Mr. Waseem  |  Group: D21, Size: 43  |  Slot: 13:00-14:00 Day: Wed  |  Room: N2 Size: 60
# CourseClass: CC  |  Professor: Dr. Talha Waheed  |  Group: A20, Size: 43  |  Slot: 08:00-09:00 Day: Thu  |  Room: N8 Size: 60
# CourseClass: CC  |  Professor: Dr. Talha Waheed  |  Group: B20, Size: 50  |  Slot: 08:00-09:00 Day: Wed  |  Room: N4 Size: 60
# CourseClass: CC  |  Professor: Dr. Talha Waheed  |  Group: C20, Size: 30  |  Slot: 10:00-11:00 Day: Tue  |  Room: N5 Size: 60
# CourseClass: CC (Lab)  |  Professor: Ms. Aaliya  |  Group: A20, Size: 43  |  Slot: 14:00-15:00 Day: Fri  |  Room: lab4 Size: 60
# CourseClass: CC (Lab)  |  Professor: Ms. Aaliya  |  Group: B20, Size: 50  |  Slot: 09:00-10:00 Day: Wed  |  Room: lab1 Size: 60
# CourseClass: CC (Lab)  |  Professor: Ms. Aaliya  |  Group: C20, Size: 30  |  Slot: 14:00-15:00 Day: Mon  |  Room: lab3 Size: 60
# CourseClass: NLP  |  Professor: Dr. Usman Ghani  |  Group: A20, Size: 43  |  Slot: 10:00-11:00 Day: Tue  |  Room: N6 Size: 60
# CourseClass: NLP  |  Professor: Dr. Usman Ghani  |  Group: B20, Size: 50  |  Slot: 08:00-09:00 Day: Tue  |  Room: N7 Size: 60
# CourseClass: NLP  |  Professor: Dr. Usman Ghani  |  Group: C20, Size: 30  |  Slot: 11:00-12:00 Day: Wed  |  Room: N8 Size: 60
# CourseClass: IPS  |  Professor: Department of Islamic Studies  |  Group: A20, Size: 43  |  Slot: 13:00-14:00 Day: Tue  |  Room: N6 Size: 60
# CourseClass: IPS  |  Professor: Department of Islamic Studies  |  Group: B20, Size: 50  |  Slot: 15:00-16:00 Day: Thu  |  Room: N3 Size: 60
# CourseClass: IPS  |  Professor: Department of Islamic Studies  |  Group: C20, Size: 30  |  Slot: 15:00-16:00 Day: Wed  |  Room: N12 Size: 60
# CourseClass: IR  |  Professor: Dr. Khaldoon  |  Group: A20, Size: 43  |  Slot: 14:00-15:00 Day: Tue  |  Room: N6 Size: 60
# CourseClass: IR  |  Professor: Dr. Khaldoon  |  Group: B20, Size: 50  |  Slot: 08:00-09:00 Day: Thu  |  Room: N7 Size: 60
# CourseClass: IR  |  Professor: Dr. Khaldoon  |  Group: C20, Size: 30  |  Slot: 09:00-10:00 Day: Mon  |  Room: N7 Size: 60
# CourseClass: CCom  |  Professor: Nauman Shafee  |  Group: A20, Size: 43  |  Slot: 08:00-09:00 Day: Mon  |  Room: N9 Size: 60
# CourseClass: CCom  |  Professor: Nauman Shafee  |  Group: B20, Size: 50  |  Slot: 15:00-16:00 Day: Tue  |  Room: N3 Size: 60
# CourseClass: CCom  |  Professor: Nauman Shafee  |  Group: C20, Size: 30  |  Slot: 09:00-10:00 Day: Thu  |  Room: N5 Size: 60
# A23
# {'Fri': {'09:00-10:00': 'PF N7', '14:00-15:00': 'FE N9'}, 'Tue': {'08:00-09:00': 'PF (Lab) lab2', '15:00-16:00': 'WP N8'}, 'Mon': {'15:00-16:00': 'AICT N6', '09:00-10:00': 'C N4'}, 'Thu': {'11:00-12:00': 'AICT (Lab) N6'}, 'Wed': {'08:00-09:00': 'DMI N6'}}
# yes
# yes
# yes
# +----------+---------------+-------------+-------------+---------------+-------------+-------------+-------------+
# | Day\Slot | 08:00-09:00   | 09:00-10:00 | 10:00-11:00 | 11:00-12:00   | 13:00-14:00 | 14:00-15:00 | 15:00-16:00 |
# +----------+---------------+-------------+-------------+---------------+-------------+-------------+-------------+
# | Mon      | -             | C N4        | -           | -             | -           | -           | AICT N6     |
# +----------+---------------+-------------+-------------+---------------+-------------+-------------+-------------+
# | Tue      | PF (Lab) lab2 | -           | -           | -             | -           | -           | WP N8       |
# +----------+---------------+-------------+-------------+---------------+-------------+-------------+-------------+
# | Wed      | DMI N6        | -           | -           | -             | -           | -           | -           |
# +----------+---------------+-------------+-------------+---------------+-------------+-------------+-------------+
# | Thu      | -             | -           | -           | AICT (Lab) N6 | -           | -           | -           |
# +----------+---------------+-------------+-------------+---------------+-------------+-------------+-------------+
# | Fri      | -             | PF N7       | -           | -             | -           | FE N9       | -           |
# +----------+---------------+-------------+-------------+---------------+-------------+-------------+-------------+
# B23
# {'Tue': {'14:00-15:00': 'PF N4', '09:00-10:00': 'AICT (Lab) N4', '13:00-14:00': 'FE N10'}, 'Mon': {'09:00-10:00': 'PF (Lab) lab1', '11:00-12:00': 'C N11'}, 'Fri': {'11:00-12:00': 'AICT N8', '14:00-15:00': 'DMI N5', '10:00-11:00': 'WP N10'}}
# yes
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00   | 10:00-11:00 | 11:00-12:00 | 13:00-14:00 | 14:00-15:00 | 15:00-16:00 |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Mon      | -           | PF (Lab) lab1 | -           | C N11       | -           | -           | -           |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Tue      | -           | AICT (Lab) N4 | -           | -           | FE N10      | PF N4       | -           |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Wed      | -           | -             | -           | -           | -           | -           | -           |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Thu      | -           | -             | -           | -           | -           | -           | -           |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Fri      | -           | -             | WP N10      | AICT N8     | -           | DMI N5      | -           |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# C23
# {'Fri': {'11:00-12:00': 'PF N2', '15:00-16:00': 'PF (Lab) lab4', '14:00-15:00': 'WP N8'}, 'Mon': {'10:00-11:00': 'AICT N6', '11:00-12:00': 'DMI N4'}, 'Tue': {'08:00-09:00': 'AICT (Lab) N3'}, 'Wed': {'13:00-14:00': 'FE N12', '14:00-15:00': 'C N3'}}
# yes
# yes
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Day\Slot | 08:00-09:00   | 09:00-10:00 | 10:00-11:00 | 11:00-12:00 | 13:00-14:00 | 14:00-15:00 | 15:00-16:00   |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Mon      | -             | -           | AICT N6     | DMI N4      | -           | -           | -             |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Tue      | AICT (Lab) N3 | -           | -           | -           | -           | -           | -             |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Wed      | -             | -           | -           | -           | FE N12      | C N3        | -             |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Thu      | -             | -           | -           | -           | -           | -           | -             |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Fri      | -             | -           | -           | PF N2       | -           | WP N8       | PF (Lab) lab4 |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# D23
# {'Tue': {'14:00-15:00': 'PF N7', '11:00-12:00': 'AICT (Lab) N5', '08:00-09:00': 'FE N6'}, 'Wed': {'14:00-15:00': 'PF (Lab) lab1', '09:00-10:00': 'WP N10'}, 'Fri': {'13:00-14:00': 'AICT N7', '15:00-16:00': 'DMI N5'}, 'Thu': {'13:00-14:00': 'C N12'}}
# yes
# +----------+-------------+-------------+-------------+---------------+-------------+---------------+-------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00 | 10:00-11:00 | 11:00-12:00   | 13:00-14:00 | 14:00-15:00   | 15:00-16:00 |
# +----------+-------------+-------------+-------------+---------------+-------------+---------------+-------------+
# | Mon      | -           | -           | -           | -             | -           | -             | -           |
# +----------+-------------+-------------+-------------+---------------+-------------+---------------+-------------+
# | Tue      | FE N6       | -           | -           | AICT (Lab) N5 | -           | PF N7         | -           |
# +----------+-------------+-------------+-------------+---------------+-------------+---------------+-------------+
# | Wed      | -           | WP N10      | -           | -             | -           | PF (Lab) lab1 | -           |
# +----------+-------------+-------------+-------------+---------------+-------------+---------------+-------------+
# | Thu      | -           | -           | -           | -             | C N12       | -             | -           |
# +----------+-------------+-------------+-------------+---------------+-------------+---------------+-------------+
# | Fri      | -           | -           | -           | -             | AICT N7     | -             | DMI N5      |
# +----------+-------------+-------------+-------------+---------------+-------------+---------------+-------------+
# A22
# {'Tue': {'10:00-11:00': 'DSA N7', '14:00-15:00': 'TW N5'}, 'Fri': {'14:00-15:00': 'DSA (Lab) lab2', '15:00-16:00': 'COAL (Lab) N10'}, 'Mon': {'14:00-15:00': 'COAL N2'}, 'Thu': {'09:00-10:00': 'LA N3', '13:00-14:00': 'DMII N9'}}
# yes
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+----------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00 | 10:00-11:00 | 11:00-12:00 | 13:00-14:00 | 14:00-15:00    | 15:00-16:00    |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+----------------+
# | Mon      | -           | -           | -           | -           | -           | COAL N2        | -              |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+----------------+
# | Tue      | -           | -           | DSA N7      | -           | -           | TW N5          | -              |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+----------------+
# | Wed      | -           | -           | -           | -           | -           | -              | -              |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+----------------+
# | Thu      | -           | LA N3       | -           | -           | DMII N9     | -              | -              |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+----------------+
# | Fri      | -           | -           | -           | -           | -           | DSA (Lab) lab2 | COAL (Lab) N10 |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+----------------+
# B22
# {'Mon': {'14:00-15:00': 'DSA N10', '15:00-16:00': 'DMII N9'}, 'Wed': {'08:00-09:00': 'DSA (Lab) lab2'}, 'Tue': {'13:00-14:00': 'TW N12'}, 'Fri': {'13:00-14:00': 'COAL N6', '10:00-11:00': 'COAL (Lab) lab2'}, 'Thu': {'15:00-16:00': 'LA N9'}}
# yes
# yes
# +----------+----------------+-------------+-----------------+-------------+-------------+-------------+-------------+
# | Day\Slot | 08:00-09:00    | 09:00-10:00 | 10:00-11:00     | 11:00-12:00 | 13:00-14:00 | 14:00-15:00 | 15:00-16:00 |
# +----------+----------------+-------------+-----------------+-------------+-------------+-------------+-------------+
# | Mon      | -              | -           | -               | -           | -           | DSA N10     | DMII N9     |
# +----------+----------------+-------------+-----------------+-------------+-------------+-------------+-------------+
# | Tue      | -              | -           | -               | -           | TW N12      | -           | -           |
# +----------+----------------+-------------+-----------------+-------------+-------------+-------------+-------------+
# | Wed      | DSA (Lab) lab2 | -           | -               | -           | -           | -           | -           |
# +----------+----------------+-------------+-----------------+-------------+-------------+-------------+-------------+
# | Thu      | -              | -           | -               | -           | -           | -           | LA N9       |
# +----------+----------------+-------------+-----------------+-------------+-------------+-------------+-------------+
# | Fri      | -              | -           | COAL (Lab) lab2 | -           | COAL N6     | -           | -           |
# +----------+----------------+-------------+-----------------+-------------+-------------+-------------+-------------+
# C22
# {'Fri': {'13:00-14:00': 'DSA N10', '10:00-11:00': 'TW N12', '15:00-16:00': 'LA N7'}, 'Tue': {'14:00-15:00': 'DSA (Lab) lab1', '13:00-14:00': 'COAL N1'}, 'Thu': {'14:00-15:00': 'COAL (Lab) N11'}, 'Wed': {'15:00-16:00': 'DMII N10'}}
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+-------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00 | 10:00-11:00 | 11:00-12:00 | 13:00-14:00 | 14:00-15:00    | 15:00-16:00 |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+-------------+
# | Mon      | -           | -           | -           | -           | -           | -              | -           |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+-------------+
# | Tue      | -           | -           | -           | -           | COAL N1     | DSA (Lab) lab1 | -           |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+-------------+
# | Wed      | -           | -           | -           | -           | -           | -              | DMII N10    |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+-------------+
# | Thu      | -           | -           | -           | -           | -           | COAL (Lab) N11 | -           |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+-------------+
# | Fri      | -           | -           | TW N12      | -           | DSA N10     | -              | LA N7       |
# +----------+-------------+-------------+-------------+-------------+-------------+----------------+-------------+
# D22
# {'Wed': {'14:00-15:00': 'DSA N5', '09:00-10:00': 'TW N7'}, 'Mon': {'15:00-16:00': 'DSA (Lab) lab3'}, 'Thu': {'09:00-10:00': 'COAL N7', '10:00-11:00': 'LA N12'}, 'Fri': {'09:00-10:00': 'COAL (Lab) lab2', '13:00-14:00': 'DMII N3'}}
# yes
# +----------+-------------+-----------------+-------------+-------------+-------------+-------------+----------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00     | 10:00-11:00 | 11:00-12:00 | 13:00-14:00 | 14:00-15:00 | 15:00-16:00    |
# +----------+-------------+-----------------+-------------+-------------+-------------+-------------+----------------+
# | Mon      | -           | -               | -           | -           | -           | -           | DSA (Lab) lab3 |
# +----------+-------------+-----------------+-------------+-------------+-------------+-------------+----------------+
# | Tue      | -           | -               | -           | -           | -           | -           | -              |
# +----------+-------------+-----------------+-------------+-------------+-------------+-------------+----------------+
# | Wed      | -           | TW N7           | -           | -           | -           | DSA N5      | -              |
# +----------+-------------+-----------------+-------------+-------------+-------------+-------------+----------------+
# | Thu      | -           | COAL N7         | LA N12      | -           | -           | -           | -              |
# +----------+-------------+-----------------+-------------+-------------+-------------+-------------+----------------+
# | Fri      | -           | COAL (Lab) lab2 | -           | -           | DMII N3     | -           | -              |
# +----------+-------------+-----------------+-------------+-------------+-------------+-------------+----------------+
# A21
# {'Thu': {'11:00-12:00': 'CN N10', '15:00-16:00': 'AI (Lab) lab1'}, 'Fri': {'11:00-12:00': 'CN (Lab) lab2', '13:00-14:00': 'SE N8', '08:00-09:00': 'MAD N1'}, 'Tue': {'09:00-10:00': 'AI N9', '13:00-14:00': 'PPSD N11', '15:00-16:00': 'SE (Lab) lab4'}}
# yes
# +----------+-------------+-------------+-------------+---------------+-------------+-------------+---------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00 | 10:00-11:00 | 11:00-12:00   | 13:00-14:00 | 14:00-15:00 | 15:00-16:00   |
# +----------+-------------+-------------+-------------+---------------+-------------+-------------+---------------+
# | Mon      | -           | -           | -           | -             | -           | -           | -             |
# +----------+-------------+-------------+-------------+---------------+-------------+-------------+---------------+
# | Tue      | -           | AI N9       | -           | -             | PPSD N11    | -           | SE (Lab) lab4 |
# +----------+-------------+-------------+-------------+---------------+-------------+-------------+---------------+
# | Wed      | -           | -           | -           | -             | -           | -           | -             |
# +----------+-------------+-------------+-------------+---------------+-------------+-------------+---------------+
# | Thu      | -           | -           | -           | CN N10        | -           | -           | AI (Lab) lab1 |
# +----------+-------------+-------------+-------------+---------------+-------------+-------------+---------------+
# | Fri      | MAD N1      | -           | -           | CN (Lab) lab2 | SE N8       | -           | -             |
# +----------+-------------+-------------+-------------+---------------+-------------+-------------+---------------+
# B21
# {'Wed': {'11:00-12:00': 'CN N5', '10:00-11:00': 'SE (Lab) lab4'}, 'Mon': {'09:00-10:00': 'CN (Lab) lab4'}, 'Fri': {'10:00-11:00': 'AI N1', '13:00-14:00': 'MAD N9'}, 'Tue': {'08:00-09:00': 'AI (Lab) lab1', '11:00-12:00': 'PPSD N9'}, 'Thu': {'14:00-15:00': 'SE N6'}}
# yes
# yes
# +----------+---------------+---------------+---------------+-------------+-------------+-------------+-------------+
# | Day\Slot | 08:00-09:00   | 09:00-10:00   | 10:00-11:00   | 11:00-12:00 | 13:00-14:00 | 14:00-15:00 | 15:00-16:00 |
# +----------+---------------+---------------+---------------+-------------+-------------+-------------+-------------+
# | Mon      | -             | CN (Lab) lab4 | -             | -           | -           | -           | -           |
# +----------+---------------+---------------+---------------+-------------+-------------+-------------+-------------+
# | Tue      | AI (Lab) lab1 | -             | -             | PPSD N9     | -           | -           | -           |
# +----------+---------------+---------------+---------------+-------------+-------------+-------------+-------------+
# | Wed      | -             | -             | SE (Lab) lab4 | CN N5       | -           | -           | -           |
# +----------+---------------+---------------+---------------+-------------+-------------+-------------+-------------+
# | Thu      | -             | -             | -             | -           | -           | SE N6       | -           |
# +----------+---------------+---------------+---------------+-------------+-------------+-------------+-------------+
# | Fri      | -             | -             | AI N1         | -           | MAD N9      | -           | -           |
# +----------+---------------+---------------+---------------+-------------+-------------+-------------+-------------+
# C21
# {'Wed': {'13:00-14:00': 'CN N11'}, 'Tue': {'15:00-16:00': 'CN (Lab) lab1', '10:00-11:00': 'AI (Lab) lab3'}, 'Fri': {'13:00-14:00': 'AI N11', '14:00-15:00': 'PPSD N1'}, 'Mon': {'14:00-15:00': 'SE N3', '13:00-14:00': 'SE (Lab) lab3'}, 'Thu': {'08:00-09:00': 'MAD N9'}}
# yes
# yes
# +----------+-------------+-------------+---------------+-------------+---------------+-------------+---------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00 | 10:00-11:00   | 11:00-12:00 | 13:00-14:00   | 14:00-15:00 | 15:00-16:00   |
# +----------+-------------+-------------+---------------+-------------+---------------+-------------+---------------+
# | Mon      | -           | -           | -             | -           | SE (Lab) lab3 | SE N3       | -             |
# +----------+-------------+-------------+---------------+-------------+---------------+-------------+---------------+
# | Tue      | -           | -           | AI (Lab) lab3 | -           | -             | -           | CN (Lab) lab1 |
# +----------+-------------+-------------+---------------+-------------+---------------+-------------+---------------+
# | Wed      | -           | -           | -             | -           | CN N11        | -           | -             |
# +----------+-------------+-------------+---------------+-------------+---------------+-------------+---------------+
# | Thu      | MAD N9      | -           | -             | -           | -             | -           | -             |
# +----------+-------------+-------------+---------------+-------------+---------------+-------------+---------------+
# | Fri      | -           | -           | -             | -           | AI N11        | PPSD N1     | -             |
# +----------+-------------+-------------+---------------+-------------+---------------+-------------+---------------+
# D21
# {'Mon': {'08:00-09:00': 'CN N12', '09:00-10:00': 'AI (Lab) N6'}, 'Wed': {'08:00-09:00': 'CN (Lab) lab4', '15:00-16:00': 'SE (Lab) lab1', '13:00-14:00': 'MAD N2'}, 'Thu': {'14:00-15:00': 'PPSD N10', '09:00-10:00': 'SE N6'}}
# yes
# yes
# yes
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Day\Slot | 08:00-09:00   | 09:00-10:00 | 10:00-11:00 | 11:00-12:00 | 13:00-14:00 | 14:00-15:00 | 15:00-16:00   |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Mon      | CN N12        | AI (Lab) N6 | -           | -           | -           | -           | -             |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Tue      | -             | -           | -           | -           | -           | -           | -             |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Wed      | CN (Lab) lab4 | -           | -           | -           | MAD N2      | -           | SE (Lab) lab1 |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Thu      | -             | SE N6       | -           | -           | -           | PPSD N10    | -             |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# | Fri      | -             | -           | -           | -           | -           | -           | -             |
# +----------+---------------+-------------+-------------+-------------+-------------+-------------+---------------+
# A20
# {'Thu': {'08:00-09:00': 'CC N8'}, 'Fri': {'14:00-15:00': 'CC (Lab) lab4'}, 'Tue': {'10:00-11:00': 'NLP N6', '13:00-14:00': 'IPS N6', '14:00-15:00': 'IR N6'}, 'Mon': {'08:00-09:00': 'CCom N9'}}
# yes
# yes
# yes
# +----------+-------------+-------------+-------------+-------------+-------------+---------------+-------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00 | 10:00-11:00 | 11:00-12:00 | 13:00-14:00 | 14:00-15:00   | 15:00-16:00 |
# +----------+-------------+-------------+-------------+-------------+-------------+---------------+-------------+
# | Mon      | CCom N9     | -           | -           | -           | -           | -             | -           |
# +----------+-------------+-------------+-------------+-------------+-------------+---------------+-------------+
# | Tue      | -           | -           | NLP N6      | -           | IPS N6      | IR N6         | -           |
# +----------+-------------+-------------+-------------+-------------+-------------+---------------+-------------+
# | Wed      | -           | -           | -           | -           | -           | -             | -           |
# +----------+-------------+-------------+-------------+-------------+-------------+---------------+-------------+
# | Thu      | CC N8       | -           | -           | -           | -           | -             | -           |
# +----------+-------------+-------------+-------------+-------------+-------------+---------------+-------------+
# | Fri      | -           | -           | -           | -           | -           | CC (Lab) lab4 | -           |
# +----------+-------------+-------------+-------------+-------------+-------------+---------------+-------------+
# B20
# {'Wed': {'08:00-09:00': 'CC N4', '09:00-10:00': 'CC (Lab) lab1'}, 'Tue': {'08:00-09:00': 'NLP N7', '15:00-16:00': 'CCom N3'}, 'Thu': {'15:00-16:00': 'IPS N3', '08:00-09:00': 'IR N7'}}
# yes
# yes
# yes
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00   | 10:00-11:00 | 11:00-12:00 | 13:00-14:00 | 14:00-15:00 | 15:00-16:00 |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Mon      | -           | -             | -           | -           | -           | -           | -           |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Tue      | NLP N7      | -             | -           | -           | -           | -           | CCom N3     |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Wed      | CC N4       | CC (Lab) lab1 | -           | -           | -           | -           | -           |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Thu      | IR N7       | -             | -           | -           | -           | -           | IPS N3      |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# | Fri      | -           | -             | -           | -           | -           | -           | -           |
# +----------+-------------+---------------+-------------+-------------+-------------+-------------+-------------+
# C20
# {'Tue': {'10:00-11:00': 'CC N5'}, 'Mon': {'14:00-15:00': 'CC (Lab) lab3', '09:00-10:00': 'IR N7'}, 'Wed': {'11:00-12:00': 'NLP N8', '15:00-16:00': 'IPS N12'}, 'Thu': {'09:00-10:00': 'CCom N5'}}
# yes
# +----------+-------------+-------------+-------------+-------------+-------------+---------------+-------------+
# | Day\Slot | 08:00-09:00 | 09:00-10:00 | 10:00-11:00 | 11:00-12:00 | 13:00-14:00 | 14:00-15:00   | 15:00-16:00 |
# +----------+-------------+-------------+-------------+-------------+-------------+---------------+-------------+
# | Mon      | -           | IR N7       | -           | -           | -           | CC (Lab) lab3 | -           |
# ...
#
# ------------- Simulated Annealing --------------
#
# CourseClass: PF  |  Professor: Dr. Awais Hassan  |  Group: A23, Size: 43  |  Slot: 14:00-15:00 Day: Fri  |  Room: lab2 Size: 60
# CourseClass: PF  |  Professor: Dr. Awais Hassan  |  Group: B23, Size: 50  |  Slot: 14:00-15:00 Day: Tue  |  Room: lab2 Size: 60
# CourseClass: PF  |  Professor: Mr. Laeeq uz Zaman  |  Group: C23, Size: 30  |  Slot: 08:00-09:00 Day: Thu  |  Room: N8 Size: 60
# CourseClass: PF  |  Professor: Ms. Maida  |  Group: D23, Size: 43  |  Slot: 13:00-14:00 Day: Fri  |  Room: N12 Size: 60
# CourseClass: PF (Lab)  |  Professor: Ms. Maida  |  Group: A23, Size: 43  |  Slot: 13:00-14:00 Day: Mon  |  Room: lab3 Size: 60
# CourseClass: PF (Lab)  |  Professor: Ms. Maida  |  Group: B23, Size: 50  |  Slot: 14:00-15:00 Day: Wed  |  Room: lab3 Size: 60
# CourseClass: PF (Lab)  |  Professor: Ms. Maida  |  Group: C23, Size: 30  |  Slot: 09:00-10:00 Day: Tue  |  Room: lab1 Size: 60
# CourseClass: PF (Lab)  |  Professor: Ms. Maida  |  Group: D23, Size: 43  |  Slot: 10:00-11:00 Day: Thu  |  Room: N1 Size: 60
# CourseClass: AICT  |  Professor: Ms. Abqa Javed  |  Group: A23, Size: 43  |  Slot: 10:00-11:00 Day: Mon  |  Room: lab3 Size: 60
# CourseClass: AICT  |  Professor: Ms. Abqa Javed  |  Group: B23, Size: 50  |  Slot: 13:00-14:00 Day: Fri  |  Room: N5 Size: 60
# CourseClass: AICT  |  Professor: Dr. Amna Zafar  |  Group: C23, Size: 30  |  Slot: 11:00-12:00 Day: Tue  |  Room: N6 Size: 60
# CourseClass: AICT  |  Professor: Dr. Amna Zafar  |  Group: D23, Size: 43  |  Slot: 10:00-11:00 Day: Wed  |  Room: N2 Size: 60
# CourseClass: AICT (Lab)  |  Professor: Ms. Abqa Javed  |  Group: A23, Size: 43  |  Slot: 11:00-12:00 Day: Mon  |  Room: N8 Size: 60
# CourseClass: AICT (Lab)  |  Professor: Ms. Abqa Javed  |  Group: B23, Size: 50  |  Slot: 10:00-11:00 Day: Thu  |  Room: N3 Size: 60
# CourseClass: AICT (Lab)  |  Professor: Dr. Amna Zafar  |  Group: C23, Size: 30  |  Slot: 15:00-16:00 Day: Mon  |  Room: N11 Size: 60
# CourseClass: AICT (Lab)  |  Professor: Dr. Amna Zafar  |  Group: D23, Size: 43  |  Slot: 11:00-12:00 Day: Wed  |  Room: lab3 Size: 60
# CourseClass: DMI  |  Professor: Waqas Ali  |  Group: A23, Size: 43  |  Slot: 10:00-11:00 Day: Tue  |  Room: N6 Size: 60
# CourseClass: DMI  |  Professor: Waqas Ali  |  Group: B23, Size: 50  |  Slot: 08:00-09:00 Day: Wed  |  Room: N8 Size: 60
# CourseClass: DMI  |  Professor: Waqas Ali  |  Group: C23, Size: 30  |  Slot: 09:00-10:00 Day: Fri  |  Room: N11 Size: 60
# CourseClass: DMI  |  Professor: Waqas Ali  |  Group: D23, Size: 43  |  Slot: 11:00-12:00 Day: Mon  |  Room: lab2 Size: 60
# CourseClass: FE  |  Professor: Humanities Department I  |  Group: A23, Size: 43  |  Slot: 15:00-16:00 Day: Tue  |  Room: N10 Size: 60
# CourseClass: FE  |  Professor: Humanities Department I  |  Group: B23, Size: 50  |  Slot: 11:00-12:00 Day: Mon  |  Room: N10 Size: 60
# CourseClass: FE  |  Professor: Humanities Department I  |  Group: C23, Size: 30  |  Slot: 11:00-12:00 Day: Wed  |  Room: N1 Size: 60
# CourseClass: FE  |  Professor: Humanities Department I  |  Group: D23, Size: 43  |  Slot: 13:00-14:00 Day: Thu  |  Room: N1 Size: 60
# CourseClass: C  |  Professor: Mathematics Department I  |  Group: A23, Size: 43  |  Slot: 08:00-09:00 Day: Mon  |  Room: N5 Size: 60
# CourseClass: C  |  Professor: Mathematics Department I  |  Group: B23, Size: 50  |  Slot: 14:00-15:00 Day: Mon  |  Room: lab1 Size: 60
# CourseClass: C  |  Professor: Mathematics Department I  |  Group: C23, Size: 30  |  Slot: 13:00-14:00 Day: Fri  |  Room: lab4 Size: 60
# CourseClass: C  |  Professor: Mathematics Department I  |  Group: D23, Size: 43  |  Slot: 10:00-11:00 Day: Tue  |  Room: N8 Size: 60
# CourseClass: WP  |  Professor: Mechanical Department I  |  Group: A23, Size: 43  |  Slot: 13:00-14:00 Day: Tue  |  Room: N6 Size: 60
# CourseClass: WP  |  Professor: Mechanical Department I  |  Group: B23, Size: 50  |  Slot: 09:00-10:00 Day: Thu  |  Room: N4 Size: 60
# CourseClass: WP  |  Professor: Mechanical Department I  |  Group: C23, Size: 30  |  Slot: 08:00-09:00 Day: Fri  |  Room: N10 Size: 60
# CourseClass: WP  |  Professor: Mechanical Department I  |  Group: D23, Size: 43  |  Slot: 09:00-10:00 Day: Wed  |  Room: lab1 Size: 60
# CourseClass: DSA  |  Professor: Mr. Nazeef ul Haq  |  Group: A22, Size: 43  |  Slot: 13:00-14:00 Day: Tue  |  Room: lab4 Size: 60
# CourseClass: DSA  |  Professor: Mr. Nazeef ul Haq  |  Group: B22, Size: 50  |  Slot: 10:00-11:00 Day: Thu  |  Room: N2 Size: 60
# CourseClass: DSA  |  Professor: Mr. Faraz  |  Group: C22, Size: 30  |  Slot: 13:00-14:00 Day: Fri  |  Room: lab3 Size: 60
# CourseClass: DSA  |  Professor: Mr. Faraz  |  Group: D22, Size: 43  |  Slot: 10:00-11:00 Day: Thu  |  Room: N5 Size: 60
# CourseClass: DSA (Lab)  |  Professor: Mr. Nazeef ul Haq  |  Group: A22, Size: 43  |  Slot: 11:00-12:00 Day: Thu  |  Room: N3 Size: 60
# CourseClass: DSA (Lab)  |  Professor: Mr. Nazeef ul Haq  |  Group: B22, Size: 50  |  Slot: 15:00-16:00 Day: Tue  |  Room: N12 Size: 60
# CourseClass: DSA (Lab)  |  Professor: Mr. Faraz  |  Group: C22, Size: 30  |  Slot: 11:00-12:00 Day: Mon  |  Room: lab3 Size: 60
# CourseClass: DSA (Lab)  |  Professor: Mr. Faraz  |  Group: D22, Size: 43  |  Slot: 14:00-15:00 Day: Fri  |  Room: N6 Size: 60
# CourseClass: TW  |  Professor: Humanities Department II  |  Group: A22, Size: 43  |  Slot: 13:00-14:00 Day: Mon  |  Room: N12 Size: 60
# CourseClass: TW  |  Professor: Humanities Department II  |  Group: B22, Size: 50  |  Slot: 10:00-11:00 Day: Wed  |  Room: N11 Size: 60
# CourseClass: TW  |  Professor: Humanities Department II  |  Group: C22, Size: 30  |  Slot: 15:00-16:00 Day: Wed  |  Room: N8 Size: 60
# CourseClass: TW  |  Professor: Humanities Department II  |  Group: D22, Size: 43  |  Slot: 10:00-11:00 Day: Fri  |  Room: N1 Size: 60
# CourseClass: COAL  |  Professor: Mr. Tauqir Ahmed  |  Group: A22, Size: 43  |  Slot: 13:00-14:00 Day: Fri  |  Room: N1 Size: 60
# CourseClass: COAL  |  Professor: Mr. Tauqir Ahmed  |  Group: B22, Size: 50  |  Slot: 11:00-12:00 Day: Fri  |  Room: N5 Size: 60
# CourseClass: COAL  |  Professor: Mr. Tauqir Ahmed  |  Group: C22, Size: 30  |  Slot: 14:00-15:00 Day: Mon  |  Room: N10 Size: 60
# CourseClass: COAL  |  Professor: Mr. Tehseen  |  Group: D22, Size: 43  |  Slot: 14:00-15:00 Day: Wed  |  Room: N3 Size: 60
# CourseClass: COAL (Lab)  |  Professor: Mr. Tehseen  |  Group: A22, Size: 43  |  Slot: 10:00-11:00 Day: Thu  |  Room: lab2 Size: 60
# CourseClass: COAL (Lab)  |  Professor: Mr. Tehseen  |  Group: B22, Size: 50  |  Slot: 08:00-09:00 Day: Tue  |  Room: lab3 Size: 60
# CourseClass: COAL (Lab)  |  Professor: Mr. Tehseen  |  Group: C22, Size: 30  |  Slot: 11:00-12:00 Day: Wed  |  Room: N12 Size: 60
# CourseClass: COAL (Lab)  |  Professor: Mr. Tehseen  |  Group: D22, Size: 43  |  Slot: 14:00-15:00 Day: Tue  |  Room: lab1 Size: 60
# CourseClass: LA  |  Professor: Mathematics Department II  |  Group: A22, Size: 43  |  Slot: 11:00-12:00 Day: Mon  |  Room: N7 Size: 60
# CourseClass: LA  |  Professor: Mathematics Department II  |  Group: B22, Size: 50  |  Slot: 09:00-10:00 Day: Tue  |  Room: N1 Size: 60
# CourseClass: LA  |  Professor: Mathematics Department II  |  Group: C22, Size: 30  |  Slot: 08:00-09:00 Day: Tue  |  Room: N10 Size: 60
# CourseClass: LA  |  Professor: Mathematics Department II  |  Group: D22, Size: 43  |  Slot: 15:00-16:00 Day: Wed  |  Room: N12 Size: 60
# CourseClass: DMII  |  Professor: Dr. Ayesha Altaf  |  Group: A22, Size: 43  |  Slot: 08:00-09:00 Day: Mon  |  Room: N4 Size: 60
# CourseClass: DMII  |  Professor: Dr. Ayesha Altaf  |  Group: B22, Size: 50  |  Slot: 15:00-16:00 Day: Thu  |  Room: N6 Size: 60
# CourseClass: DMII  |  Professor: Dr. Ayesha Altaf  |  Group: C22, Size: 30  |  Slot: 13:00-14:00 Day: Mon  |  Room: N11 Size: 60
# CourseClass: DMII  |  Professor: Dr. Ayesha Altaf  |  Group: D22, Size: 43  |  Slot: 13:00-14:00 Day: Tue  |  Room: lab3 Size: 60
# CourseClass: CN  |  Professor: Dr. Junaid Arshad  |  Group: A21, Size: 43  |  Slot: 13:00-14:00 Day: Tue  |  Room: N1 Size: 60
# CourseClass: CN  |  Professor: Dr. Junaid Arshad  |  Group: B21, Size: 50  |  Slot: 09:00-10:00 Day: Wed  |  Room: N5 Size: 60
# CourseClass: CN  |  Professor: Dr. Junaid Arshad  |  Group: C21, Size: 30  |  Slot: 11:00-12:00 Day: Tue  |  Room: N4 Size: 60
# CourseClass: CN  |  Professor: Ms. Aroosh  |  Group: D21, Size: 43  |  Slot: 09:00-10:00 Day: Wed  |  Room: N3 Size: 60
# CourseClass: CN (Lab)  |  Professor: Ms. Aroosh  |  Group: A21, Size: 43  |  Slot: 10:00-11:00 Day: Thu  |  Room: N10 Size: 60
# CourseClass: CN (Lab)  |  Professor: Ms. Aroosh  |  Group: B21, Size: 50  |  Slot: 09:00-10:00 Day: Thu  |  Room: N7 Size: 60
# CourseClass: CN (Lab)  |  Professor: Ms. Aroosh  |  Group: C21, Size: 30  |  Slot: 08:00-09:00 Day: Tue  |  Room: N3 Size: 60
# CourseClass: CN (Lab)  |  Professor: Ms. Aroosh  |  Group: D21, Size: 43  |  Slot: 11:00-12:00 Day: Tue  |  Room: lab4 Size: 60
# CourseClass: AI  |  Professor: Prof. Dr. M. Aslam  |  Group: B21, Size: 50  |  Slot: 15:00-16:00 Day: Mon  |  Room: N7 Size: 60
# CourseClass: AI  |  Professor: Mr. Samyan Qayyum  |  Group: A21, Size: 43  |  Slot: 15:00-16:00 Day: Fri  |  Room: lab4 Size: 60
# CourseClass: AI  |  Professor: Mr. Samyan Qayyum  |  Group: C21, Size: 30  |  Slot: 10:00-11:00 Day: Thu  |  Room: N8 Size: 60
# CourseClass: AI (Lab)  |  Professor: Ms. Tazeem  |  Group: A21, Size: 43  |  Slot: 11:00-12:00 Day: Fri  |  Room: lab3 Size: 60
# CourseClass: AI (Lab)  |  Professor: Ms. Tazeem  |  Group: B21, Size: 50  |  Slot: 13:00-14:00 Day: Wed  |  Room: N1 Size: 60
# CourseClass: AI (Lab)  |  Professor: Ms. Tazeem  |  Group: C21, Size: 30  |  Slot: 14:00-15:00 Day: Mon  |  Room: N4 Size: 60
# CourseClass: AI (Lab)  |  Professor: Ms. Tazeem  |  Group: D21, Size: 43  |  Slot: 11:00-12:00 Day: Mon  |  Room: N2 Size: 60
# CourseClass: PPSD  |  Professor: Dr. Faiza Iqbal  |  Group: A21, Size: 43  |  Slot: 13:00-14:00 Day: Thu  |  Room: lab2 Size: 60
# CourseClass: PPSD  |  Professor: Dr. Faiza Iqbal  |  Group: B21, Size: 50  |  Slot: 15:00-16:00 Day: Fri  |  Room: N12 Size: 60
# CourseClass: PPSD  |  Professor: Dr. Faiza Iqbal  |  Group: C21, Size: 30  |  Slot: 15:00-16:00 Day: Thu  |  Room: N11 Size: 60
# CourseClass: PPSD  |  Professor: Dr. Faiza Iqbal  |  Group: D21, Size: 43  |  Slot: 10:00-11:00 Day: Thu  |  Room: N4 Size: 60
# CourseClass: SE  |  Professor: Mr. Aatif Hussain  |  Group: A21, Size: 43  |  Slot: 15:00-16:00 Day: Thu  |  Room: N8 Size: 60
# CourseClass: SE  |  Professor: Mr. Aatif Hussain  |  Group: B21, Size: 50  |  Slot: 11:00-12:00 Day: Thu  |  Room: N12 Size: 60
# CourseClass: SE  |  Professor: Prof. Dr. Shazia Arshad  |  Group: C21, Size: 30  |  Slot: 15:00-16:00 Day: Tue  |  Room: N2 Size: 60
# CourseClass: SE  |  Professor: Prof. Dr. Shazia Arshad  |  Group: D21, Size: 43  |  Slot: 13:00-14:00 Day: Fri  |  Room: N6 Size: 60
# CourseClass: SE (Lab)  |  Professor: Mr. Laeeq uz Zaman  |  Group: A21, Size: 43  |  Slot: 09:00-10:00 Day: Thu  |  Room: N5 Size: 60
# CourseClass: SE (Lab)  |  Professor: Mr. Laeeq uz Zaman  |  Group: B21, Size: 50  |  Slot: 15:00-16:00 Day: Thu  |  Room: N10 Size: 60
# CourseClass: SE (Lab)  |  Professor: Mr. Laeeq uz Zaman  |  Group: C21, Size: 30  |  Slot: 14:00-15:00 Day: Thu  |  Room: lab1 Size: 60
# CourseClass: SE (Lab)  |  Professor: Mr. Laeeq uz Zaman  |  Group: D21, Size: 43  |  Slot: 09:00-10:00 Day: Fri  |  Room: N2 Size: 60
# CourseClass: MAD  |  Professor: Dr. Amjad Farooq  |  Group: A21, Size: 43  |  Slot: 14:00-15:00 Day: Wed  |  Room: N1 Size: 60
# CourseClass: MAD  |  Professor: Dr. Amjad Farooq  |  Group: B21, Size: 50  |  Slot: 08:00-09:00 Day: Thu  |  Room: N6 Size: 60
# CourseClass: MAD  |  Professor: Dr. Amjad Farooq  |  Group: C21, Size: 30  |  Slot: 13:00-14:00 Day: Wed  |  Room: N5 Size: 60
# CourseClass: MAD  |  Professor: Mr. Waseem  |  Group: D21, Size: 43  |  Slot: 14:00-15:00 Day: Mon  |  Room: N9 Size: 60
# CourseClass: CC  |  Professor: Dr. Talha Waheed  |  Group: A20, Size: 43  |  Slot: 09:00-10:00 Day: Mon  |  Room: N6 Size: 60
# CourseClass: CC  |  Professor: Dr. Talha Waheed  |  Group: B20, Size: 50  |  Slot: 14:00-15:00 Day: Tue  |  Room: N2 Size: 60
# CourseClass: CC  |  Professor: Dr. Talha Waheed  |  Group: C20, Size: 30  |  Slot: 13:00-14:00 Day: Tue  |  Room: N5 Size: 60
# CourseClass: CC (Lab)  |  Professor: Ms. Aaliya  |  Group: A20, Size: 43  |  Slot: 11:00-12:00 Day: Wed  |  Room: N10 Size: 60
# CourseClass: CC (Lab)  |  Professor: Ms. Aaliya  |  Group: B20, Size: 50  |  Slot: 09:00-10:00 Day: Tue  |  Room: N12 Size: 60
# CourseClass: CC (Lab)  |  Professor: Ms. Aaliya  |  Group: C20, Size: 30  |  Slot: 09:00-10:00 Day: Wed  |  Room: N1 Size: 60
# CourseClass: NLP  |  Professor: Dr. Usman Ghani  |  Group: A20, Size: 43  |  Slot: 15:00-16:00 Day: Fri  |  Room: N9 Size: 60
# CourseClass: NLP  |  Professor: Dr. Usman Ghani  |  Group: B20, Size: 50  |  Slot: 15:00-16:00 Day: Tue  |  Room: lab3 Size: 60
# CourseClass: NLP  |  Professor: Dr. Usman Ghani  |  Group: C20, Size: 30  |  Slot: 14:00-15:00 Day: Wed  |  Room: N9 Size: 60
# CourseClass: IPS  |  Professor: Department of Islamic Studies  |  Group: A20, Size: 43  |  Slot: 10:00-11:00 Day: Mon  |  Room: lab4 Size: 60
# CourseClass: IPS  |  Professor: Department of Islamic Studies  |  Group: B20, Size: 50  |  Slot: 11:00-12:00 Day: Thu  |  Room: lab2 Size: 60
# CourseClass: IPS  |  Professor: Department of Islamic Studies  |  Group: C20, Size: 30  |  Slot: 14:00-15:00 Day: Fri  |  Room: N10 Size: 60
# CourseClass: IR  |  Professor: Dr. Khaldoon  |  Group: A20, Size: 43  |  Slot: 13:00-14:00 Day: Wed  |  Room: N11 Size: 60
# CourseClass: IR  |  Professor: Dr. Khaldoon  |  Group: B20, Size: 50  |  Slot: 13:00-14:00 Day: Mon  |  Room: N7 Size: 60
# CourseClass: IR  |  Professor: Dr. Khaldoon  |  Group: C20, Size: 30  |  Slot: 13:00-14:00 Day: Thu  |  Room: N4 Size: 60
# CourseClass: CCom  |  Professor: Nauman Shafee  |  Group: A20, Size: 43  |  Slot: 14:00-15:00 Day: Fri  |  Room: N4 Size: 60
# CourseClass: CCom  |  Professor: Nauman Shafee  |  Group: B20, Size: 50  |  Slot: 13:00-14:00 Day: Fri  |  Room: N4 Size: 60
# CourseClass: CCom  |  Professor: Nauman Shafee  |  Group: C20, Size: 30  |  Slot: 08:00-09:00 Day: Thu  |  Room: lab4 Size: 60
# Score:  0.9062980030721967
